# %% [markdown]
# ## full_data에서 pdf 경로 추출 후 json 파일로 저장

# %%
# 최종코드
import json
import os

def extract_pdf_register(file_path, output_file_path):
    print("Starting the extraction process...")

    # JSON 파일 읽기
    with open(file_path, 'r', encoding='utf-8') as json_file:
        print(f"Reading data from {file_path}...")
        done_data = json.load(json_file)

    data = done_data.get('items', [])
    total_items = len(data)
    print(f"Total items found: {total_items}")

    # 'pdf_rewrite_register', 'pdf_register', 'pdf_open' 중 하나라도 있는 'applicationNumber' 추출
    pdf_register_dict = {}

    for index, item in enumerate(data):
        pdf_path = None

        # 중요도 순서에 따라 값 선택
        if 'pdf_rewrite_register' in item and item['pdf_rewrite_register'] != 'null':
            pdf_path = item['pdf_rewrite_register']
        elif 'pdf_register' in item and item['pdf_register'] != 'null':
            pdf_path = item['pdf_register']
        elif 'pdf_open' in item and item['pdf_open'] != 'null':
            pdf_path = item['pdf_open']

        if pdf_path:
            application_number = item['applicationNumber']
            pdf_register_dict[application_number] = pdf_path
            if (index + 1) % 1000 == 0 or index == total_items - 1:
                print(f"Processed {index + 1}/{total_items} items. Current valid PDFs: {len(pdf_register_dict)}")
        else:
            if (index + 1) % 1000 == 0 or index == total_items - 1:
                print(f"Processed {index + 1}/{total_items} items. No valid PDF path found for this item.")

    # 딕셔너리를 JSON 파일로 저장
    with open(output_file_path, 'w', encoding='utf-8') as json_file:
        print(f"Saving extracted data to {output_file_path}...")
        json.dump(pdf_register_dict, json_file, ensure_ascii=False, indent=4)

    print(f"PDF 경로가 포함된 특허번호가 {len(pdf_register_dict)}개 저장되었습니다.")

if __name__ == "__main__":
    # 파일 경로 설정
    input_file_path = '/media/user/datadisk/Patent_data/full_data.json'
    output_file_path = 'pdf_register_data.json'
    
    extract_pdf_register(input_file_path, output_file_path)
# Out:
# Starting the extraction process...
# Reading data from /media/user/datadisk/Patent_data/full_data.json...
# Total items found: 147861
# Processed 1000/147861 items. Current valid PDFs: 1000
# Processed 2000/147861 items. Current valid PDFs: 2000
# Processed 3000/147861 items. Current valid PDFs: 3000
# Processed 4000/147861 items. Current valid PDFs: 4000
# Processed 5000/147861 items. Current valid PDFs: 5000
# Processed 6000/147861 items. Current valid PDFs: 6000
# Processed 7000/147861 items. Current valid PDFs: 7000
# Processed 8000/147861 items. Current valid PDFs: 8000
# Processed 9000/147861 items. Current valid PDFs: 9000
# Processed 10000/147861 items. Current valid PDFs: 10000
# Processed 11000/147861 items. Current valid PDFs: 11000
# Processed 12000/147861 items. Current valid PDFs: 12000
# Processed 13000/147861 items. Current valid PDFs: 13000
# Processed 14000/147861 items. Current valid PDFs: 14000
# Processed 15000/147861 items. Current valid PDFs: 15000
# Processed 16000/147861 items. Current valid PDFs: 15999
# Processed 17000/147861 items. Current valid PDFs: 16999
# Processed 18000/147861 items. Current valid PDFs: 17999
# Processed 19000/147861 items. Current valid PDFs: 18999
# Processed 20000/147861 items. Current valid PDFs: 19999
# Processed 21000/147861 items. Current valid PDFs: 20999
# Processed 22000/147861 items. Current valid PDFs: 21999
# Processed 23000/147861 items. Current valid PDFs: 22999
# Processed 24000/147861 items. Current valid PDFs: 23999
# Processed 25000/147861 items. Current valid PDFs: 24999
# Processed 26000/147861 items. Current valid PDFs: 25999
# Processed 27000/147861 items. Current valid PDFs: 26999
# Processed 28000/147861 items. Current valid PDFs: 27999
# Processed 29000/147861 items. Current valid PDFs: 28999
# Processed 30000/147861 items. Current valid PDFs: 29999
# Processed 31000/147861 items. Current valid PDFs: 30999
# Processed 32000/147861 items. Current valid PDFs: 31999
# Processed 33000/147861 items. Current valid PDFs: 32999
# Processed 34000/147861 items. Current valid PDFs: 33999
# Processed 35000/147861 items. Current valid PDFs: 34999
# Processed 36000/147861 items. Current valid PDFs: 35999
# Processed 37000/147861 items. Current valid PDFs: 36999
# Processed 38000/147861 items. Current valid PDFs: 37999
# Processed 39000/147861 items. Current valid PDFs: 38999
# Processed 40000/147861 items. No valid PDF path found for this item.
# Processed 41000/147861 items. No valid PDF path found for this item.
# Processed 42000/147861 items. No valid PDF path found for this item.
# Processed 43000/147861 items. No valid PDF path found for this item.
# Processed 44000/147861 items. No valid PDF path found for this item.
# Processed 45000/147861 items. No valid PDF path found for this item.
# Processed 46000/147861 items. No valid PDF path found for this item.
# Processed 47000/147861 items. No valid PDF path found for this item.
# Processed 48000/147861 items. No valid PDF path found for this item.
# Processed 49000/147861 items. No valid PDF path found for this item.
# Processed 50000/147861 items. No valid PDF path found for this item.
# Processed 51000/147861 items. No valid PDF path found for this item.
# Processed 52000/147861 items. No valid PDF path found for this item.
# Processed 53000/147861 items. No valid PDF path found for this item.
# Processed 54000/147861 items. No valid PDF path found for this item.
# Processed 55000/147861 items. No valid PDF path found for this item.
# Processed 56000/147861 items. No valid PDF path found for this item.
# Processed 57000/147861 items. No valid PDF path found for this item.
# Processed 58000/147861 items. No valid PDF path found for this item.
# Processed 59000/147861 items. No valid PDF path found for this item.
# Processed 60000/147861 items. No valid PDF path found for this item.
# Processed 61000/147861 items. No valid PDF path found for this item.
# Processed 62000/147861 items. No valid PDF path found for this item.
# Processed 63000/147861 items. No valid PDF path found for this item.
# Processed 64000/147861 items. No valid PDF path found for this item.
# Processed 65000/147861 items. No valid PDF path found for this item.
# Processed 66000/147861 items. No valid PDF path found for this item.
# Processed 67000/147861 items. No valid PDF path found for this item.
# Processed 68000/147861 items. No valid PDF path found for this item.
# Processed 69000/147861 items. No valid PDF path found for this item.
# Processed 70000/147861 items. No valid PDF path found for this item.
# Processed 71000/147861 items. No valid PDF path found for this item.
# Processed 72000/147861 items. No valid PDF path found for this item.
# Processed 73000/147861 items. No valid PDF path found for this item.
# Processed 74000/147861 items. No valid PDF path found for this item.
# Processed 75000/147861 items. No valid PDF path found for this item.
# Processed 76000/147861 items. No valid PDF path found for this item.
# Processed 77000/147861 items. No valid PDF path found for this item.
# Processed 78000/147861 items. No valid PDF path found for this item.
# Processed 79000/147861 items. No valid PDF path found for this item.
# Processed 80000/147861 items. No valid PDF path found for this item.
# Processed 81000/147861 items. No valid PDF path found for this item.
# Processed 82000/147861 items. No valid PDF path found for this item.
# Processed 83000/147861 items. No valid PDF path found for this item.
# Processed 84000/147861 items. No valid PDF path found for this item.
# Processed 85000/147861 items. No valid PDF path found for this item.
# Processed 86000/147861 items. No valid PDF path found for this item.
# Processed 87000/147861 items. No valid PDF path found for this item.
# Processed 88000/147861 items. No valid PDF path found for this item.
# Processed 89000/147861 items. No valid PDF path found for this item.
# Processed 90000/147861 items. No valid PDF path found for this item.
# Processed 91000/147861 items. No valid PDF path found for this item.
# Processed 92000/147861 items. No valid PDF path found for this item.
# Processed 93000/147861 items. No valid PDF path found for this item.
# Processed 94000/147861 items. No valid PDF path found for this item.
# Processed 95000/147861 items. No valid PDF path found for this item.
# Processed 96000/147861 items. No valid PDF path found for this item.
# Processed 97000/147861 items. No valid PDF path found for this item.
# Processed 98000/147861 items. No valid PDF path found for this item.
# Processed 99000/147861 items. No valid PDF path found for this item.
# Processed 100000/147861 items. No valid PDF path found for this item.
# Processed 101000/147861 items. No valid PDF path found for this item.
# Processed 102000/147861 items. No valid PDF path found for this item.
# Processed 103000/147861 items. No valid PDF path found for this item.
# Processed 104000/147861 items. No valid PDF path found for this item.
# Processed 105000/147861 items. No valid PDF path found for this item.
# Processed 106000/147861 items. No valid PDF path found for this item.
# Processed 107000/147861 items. No valid PDF path found for this item.
# Processed 108000/147861 items. No valid PDF path found for this item.
# Processed 109000/147861 items. No valid PDF path found for this item.
# Processed 110000/147861 items. No valid PDF path found for this item.
# Processed 111000/147861 items. No valid PDF path found for this item.
# Processed 112000/147861 items. No valid PDF path found for this item.
# Processed 113000/147861 items. No valid PDF path found for this item.
# Processed 114000/147861 items. No valid PDF path found for this item.
# Processed 115000/147861 items. No valid PDF path found for this item.
# Processed 116000/147861 items. No valid PDF path found for this item.
# Processed 117000/147861 items. No valid PDF path found for this item.
# Processed 118000/147861 items. No valid PDF path found for this item.
# Processed 119000/147861 items. No valid PDF path found for this item.
# Processed 120000/147861 items. No valid PDF path found for this item.
# Processed 121000/147861 items. No valid PDF path found for this item.
# Processed 122000/147861 items. No valid PDF path found for this item.
# Processed 123000/147861 items. No valid PDF path found for this item.
# Processed 124000/147861 items. No valid PDF path found for this item.
# Processed 125000/147861 items. No valid PDF path found for this item.
# Processed 126000/147861 items. No valid PDF path found for this item.
# Processed 127000/147861 items. No valid PDF path found for this item.
# Processed 128000/147861 items. No valid PDF path found for this item.
# Processed 129000/147861 items. No valid PDF path found for this item.
# Processed 130000/147861 items. No valid PDF path found for this item.
# Processed 131000/147861 items. No valid PDF path found for this item.
# Processed 132000/147861 items. No valid PDF path found for this item.
# Processed 133000/147861 items. No valid PDF path found for this item.
# Processed 134000/147861 items. No valid PDF path found for this item.
# Processed 135000/147861 items. No valid PDF path found for this item.
# Processed 136000/147861 items. No valid PDF path found for this item.
# Processed 137000/147861 items. No valid PDF path found for this item.
# Processed 138000/147861 items. No valid PDF path found for this item.
# Processed 139000/147861 items. No valid PDF path found for this item.
# Processed 140000/147861 items. No valid PDF path found for this item.
# Processed 141000/147861 items. No valid PDF path found for this item.
# Processed 142000/147861 items. No valid PDF path found for this item.
# Processed 143000/147861 items. No valid PDF path found for this item.
# Processed 144000/147861 items. No valid PDF path found for this item.
# Processed 145000/147861 items. No valid PDF path found for this item.
# Processed 146000/147861 items. No valid PDF path found for this item.
# Processed 147000/147861 items. No valid PDF path found for this item.
# PDF 경로가 포함된 특허번호가 39217개 저장되었습니다.

# %%
# null, null, null 찾기
import json

def find_and_print_application(file_path, target_application_number):
    print(f"Searching for application number: {target_application_number}")

    try:
        with open(file_path, 'r', encoding='utf-8') as json_file:
            data = json.load(json_file)
            
        items = data.get('items', [])
        
        found = False
        for item in items:
            if item.get('applicationNumber') == target_application_number:
                print("Found matching application. Details:")
                print(json.dumps(item, ensure_ascii=False, indent=2))
                found = True
                break
        
        if not found:
            print(f"No item found with application number: {target_application_number}")

    except FileNotFoundError:
        print(f"Error: File not found at {file_path}")
    except json.JSONDecodeError:
        print(f"Error: Unable to parse JSON from the file at {file_path}")
    except Exception as e:
        print(f"An unexpected error occurred: {str(e)}")

if __name__ == "__main__":
    file_path = '/media/user/datadisk/Patent_data/full_data.json'
    target_application_number = '1020170103960'
    
    find_and_print_application(file_path, target_application_number)
# Out:
# Searching for application number: 1020170103960
# Found matching application. Details:
# {
#   "applicantName": "박배균",
#   "applicationDate": "20170817",
#   "applicationNumber": "1020170103960",
#   "astrtCont": "상술한 기술적 과제를 해결하기 위해 본 발명에 따른 장례식장 운영시스템은 다수의 장례식장을 인수하여 홍보하되 장례의전행사를 주관하며, 장례의전행사에 필요한 장례용품을 관리하는 사업운영모듈과, 인수된 장례식장을 운영함과 동시에 장례의전행사가 필요한 고객을 유치하는 사원을 모집하며, 모집된 사원과 고객의 정보를 상기 사업운영모듈(100)에 전송하여 관리하고, 장례의전행사를 진행한 고객에 의해 입력된 사원의 기여도정보를 고객의 이동단말기를 통하여 전송받는 고객관리모듈(200) 및 상기 고객관리모듈(200)의 기여도정보를 전송받아 사원에게 지급할 수당을 결정하고, 결정된 수당정보를 상기 사업운영모듈(100)에 전송하는 지급관리모듈(300)을 포함하되, 상기 사업운영모듈은 상기 고객관리모듈에 의해 모집된 각각의 사원에게 서로 다른 영업코드를 부여하여 상기 고객관리모듈을 통해 관리될 수 있도록 하며, 상기 지급관리모듈을 통한 사원의 수당은 유치한 고객이 상기 사업운영모듈에 장례의전행사를 요청하여 접수번호를 할당한 경우에만 지급될 수 있도록 하는 것을 특징으로 한다.",
#   "bigDrawing": "http://plus.kipris.or.kr/kiprisplusws/fileToss.jsp?arg=2ba38663aa11ff0f6ca91af6061a2e00058c93a496ea3709d29d52ffbe6a5a794e1b32abe19785e66f5cd5667501b348bf4f348288e035692501371e1bc66e4ea55c937cf32db9bf",
#   "drawing": "http://plus.kipris.or.kr/kiprisplusws/fileToss.jsp?arg=ed43a0609e94d6e22d01c5c32ba711cf3c3d0e4fad4a790c711892cfd38fd7bbe1ae25276a816ecb78898f5b428eca6f4704788214babdb3e805633a7d643ff40c9791b0864ece8c",
#   "indexNo": "1",
#   "inventionTitle": "장례식장 운영시스템",
#   "ipcNumber": "G06Q 50/10|G06Q 30/02|G06Q 10/06",
#   "openDate": null,
#   "openNumber": null,
#   "publicationDate": "20181228",
#   "publicationNumber": null,
#   "registerDate": "20181221",
#   "registerNumber": "1019336320000",
#   "registerStatus": "등록",
#   "title": "장례식장 운영시스템",
#   "entire_text": " \n[ 발명의 명칭 ]\n장례식장 운영시스템INTEGRATED FUNERAL OPERATION SYSTEM \n[ 기술분야 ]\n본 발명은 인수한 장례식장을 브랜드화하며, 해당 장례식장을 활용하여 장례의전행사를 실시하고자 하는 고객을 용이하게 유치할 수 있을 뿐만 아니라, 인수한 장례식장의 서비스의 질을 개선할 수 있는 장례식장 운영시스템에 관한 것이다.  \n[ 배경기술 ]\n일반적으로 인간은 죽음에 이르게 되면 고인의 유족들은 고인의 죽음을 애도하면서 장례절차를 치르게 되는데 이러한 장례절차는 간단하지가 않아 갑자기 상을 당하게 되는 경우 상주들은 당황하여 장례절차를 잘 챙기지 못할 뿐만 아니라 장례절차에 소요되는 여러 가지 물품을 비싼 비용으로 구입하게 되며, 특히 핵가족화로 인해 자녀 수가 감소하여 상주들의 숫자가 적어 장례절차를 치르는데 많은 어려움을 겪고 있는 실정이다. 종래의 장례 서비스 시스템은 장례 서비스 대행업체가 고객들을 대상으로 회원 유치하여 매월 회비를 받아 운영하고, 회원으로부터 관혼상제 서비스 요청에 따라 장례 서비스 제공업체에 장례 서비스를 요청하여 관혼상제에 관련된 용역 서비스를 대행함에 의해 장례 서비스가 기본적으로 이루어지도록 하고 있다. 예를 들면, 회원이 매월 일정금액을 일정기간 동안 상조회사에 회비로 납부하는 상태에서 회원의 가족 중 한 명이 사망하게 되는 경우, 회원은 상조회사에 장례 서비스를 요청하고, 이 요청에 따라 상조회사는 기설정된 계약 내용에 따라 장례 서비스 제공업체에 장례 서비스를 제공할 것을 요청하고, 상기 장례 서비스 제공업체는 요청된 장례 서비스에 따라 해당 회원에게 장례절차를 진행하고, 상기 상조회사로부터 장례 서비스에 대한 비용을 지급받게 된다. 이러한 장례 서비스 시스템의 중소업체 규모의 상조회사들이 난립하고 있어 신뢰성이 저하되고, 그 중 일부 회사는 온라인을 통해 선불 할부식으로 월납 회원을 모집하고 있는데, 회원이 납부한 회비에 대한 지급 보장이 없기 때문에 상조회사의 파산 또는 고의로 부도를 낸다거나 회원이 중도 해지할 경우 납부를 회비를 환급받지 못하는 경우가 있고, 장례서비스의 질(質)이 보장되지 않는 등 문제점이 많았다.  상술한 종래의 문제점을 해결하기 위해 대한민국등록특허 제10-1228134호인 '인터넷 기반의 장례 서비스 사전 제시형 후불식 장례 서비스 시스템'이 개시되어 있으며, 그 시스템을 간략하게 설명하면 고객으로부터 장례 서비스 가입 요청시, 고객의 상황에 맞는 장례 상품 선택 및 회원 가입 절차를 수행할 수 있도록 제어하고, 고객의 정보만으로 회원 자격이 부여된 고객의 클라이언트부로부터 장례 서비스 요청시, 회원이 기선택한 장례 상품의 목록에 대한 장례 서비스정보를 장례 담당자 단말기로 전송하여 장례 서비스의 제공을 요청하는 장례 서비스 운영부와 고객으로부터 장례 서비스 가입 요청시, 고객의 상황에 맞는 장례 서비스를 선택할 수 있도록 장례 상품에 대한 비교 정보를 목록별로 분류한 장례 상품 선택 인터페이스를 고객의 클라이언트부로 전송하는 장례 상품 선택부와, 고객의 클라이언트부를 통해 입력된 고객정보를 등록하여 회원 가입처리하고, 고객의 정보를 확인하여, 회원 자격을 부여하는 회원 관리부와, 회원에게 장례 서비스 제공의 종료시, 장례 상품에 대한 결제를 후불식으로 정산하여 고객의 클라이언트부로 정산된 장례비의 지급을 요청하는 장례비용 정산부를 포함하는 구성으로 이루어져 있다. 하여, 장례 서비스를 사전에 제시할 수 있도록 하여 고객의 상황에 맞는 장례 상품을 용이하게 선택할 수 있도록 하고, 고객이 정보를 입력하면 고객 정보를 검토 후 고객에게 회원 자격을 부여하며, 장례 행사 발생시, 장례 서비스 제공에 대한 장례비용은 후불식으로 정산할 수 있도록 하여 고객의 편의성을 향상시킬 수 있다는 장점이 있었다. 그러나, 이러한 종래기술은 몇가지 현실적인 문제점을 안고 있는데 그 문제점이란 고객이 장례 서비스 제공서버에 접속하여 장례에 필요한 상품을 선택할 수 있도록 하였으나, 실제 상을 당한 고객이 이러한 상품을 선택하거나 선택한다고 하더라도 회원가입을 위해 자신의 개인정보를 회원관리부에 접속하여 회원가입을 할만한 심적상황이 아닌 상태이기에 그 효율성이 떨어진다는 문제점이 있었다.  \n[ 발명의 개요 ]\n \n[ 해결하려는 과제 ]\n본 발명은 상술한 문제점을 해결하기 위해 제안된 것으로, 상을 당한 고객이 특별히 인터넷에 접속하여 회원가입을 하지 않더라도, 최적의 서비스를 제공받을 수 있는 체계화된 고객관리서비스 시스템을 확보하고, 운영자 입장에서 복수개의 프랜차이즈화된 브랜치 장례식장들을 효율적으로 관리하는 것이 가능하게 하는 장례식장 운영시스템을 제공하는 것을 목적으로 한다.  \n[ 과제의 해결 수단 ]\n상술한 기술적 과제를 해결하기 위해 본 발명에 따른 장례식장 운영시스템은  다수의 장례식장을 인수하여 홍보하되 장례의전행사를 주관하며, 장례의전행사에 필요한 장례용품을 관리하는 사업운영모듈과, 인수된 장례식장을 운영함과 동시에 장례의전행사가 필요한 고객을 유치하는 사원을 모집하며, 모집된 사원과 고객의 정보를 상기 사업운영모듈(100)에 전송하여 관리하고, 장례의전행사를 진행한 고객에 의해 입력된 사원의 기여도정보를 고객의 이동단말기를 통하여 전송받는 고객관리모듈(200) 및 상기 고객관리모듈(200)의 기여도정보를 전송받아 사원에게 지급할 수당을 결정하고, 결정된 수당정보를 상기 사업운영모듈(100)에 전송하는 지급관리모듈(300)을 포함하되, 상기 사업운영모듈은 상기 고객관리모듈에 의해 모집된 각각의 사원에게 서로 다른 영업코드를 부여하여 상기 고객관리모듈을 통해 관리될 수 있도록 하며, 상기 지급관리모듈을 통한 사원의 수당은 유치한 고객이 상기 사업운영모듈에 장례의전행사를 요청하여 접수번호를 할당한 경우에만 지급될 수 있도록 하는 것을 특징으로 한다. 또한 상기 고객관리모듈을 통한 사원의 모집은 상기 사업운영모듈을 통해 장례식장을 인수한 이후에 실행하도록 하며, 인수한 장례식장과 동일지역 내에서 사원을 모집하여 장례식장의 운영이 이루어질 수 있도록 하는 것이 바람직하다. 또한 상기 고객관리모듈을 통해 유치하고자 하는 고객은 모집한 사원의 이동단말기에 저장된 연락처에 한하여 문자로 발송하되 해당 문자에는 상기 사업운영모듈에서 제공하는 이동단말기에 내려받기 가능한 어플리케이션이 링크되어 장례의전행사의 신청정보 및 상기 고객관리모듈로 전송되는 기여도정보를 상기 사업운영모듈에 포인트로 전송할 수 있도록 하는 것이 바람직하다. 또한 상기 장례용품은 고인의 영상물, 선두차장식 및 추모보석 중 적어도 어느 하나를 포함하되, 상기 추모보석은 인수한 장례식장에 보관가능하도록 구비되어 고객이 용이하게 방문하여 추모할 수 있도록 하는 것이 바람직하다.  \n[ 발명의 효과 ]\n본 발명에 따르면, 종래와는 차별적으로 고객관리모듈을 통해 모집된 사원에 의해 회원등록된 고객이 장례의전행사를 사업운영모듈에 요청하는 경우, 해당 고객을 유치한 사원이 고객을 도와 장례에 기여하여 장례의전행사를 진행할 수 있도록 함으로써, 원활한 장례의전행사를 진행할 수 있는 효과를 갖게 된다. 또한 종래와는 차별적으로 고객의 장례의전행사에 참여한 사원의 기여도에 따라 고객이 해당 영업자의 포상을 주도적으로 실시할 수 있도록 함으로써, 사원의 업무능력을 고객으로부터 평가받을 수 있는 효과를 갖게 된다.  \n[ 도면의 간단한 설명 ]\n 도 1은 본 발명에 따른 장례식장 운영시스템의 개념도. 도 2는 본 발명에 따른 장례식장 운영시스템의 사업운영모듈 세부개념도. 도 3은 본 발명에 따른 장례식장 운영시스템의 고객관리모듈 세부개념도. 도 4는 본 발명에 따른 장례식장 운영시스템의 지급관리모듈 세부개념도.  \n[ 발명을 실시하기 위한 구체적인 내용 ]\n이하, 첨부된 도면을 참조하여 본 발명의 바람직한 실시예에 따른 장례식장 운영시스템(이하, 간략하게 '운영시스템'이라 한다)에 관하여 상세히 설명하도록 한다. 먼저, 도 1에 도시한 바와 같이, 본 발명에 따른 운영시스템(1)은 크게 사업운영모듈(100), 고객관리모듈(200) 및  ...
#   "section_text": "일반적으로 인간은 죽음에 이르게 되면 고인의 유족들은 고인의 죽음을 애도하면서 장례절차를 치르게 되는데 이러한 장례절차는 간단하지가 않아 갑자기 상을 당하게 되는 경우 상주들은 당황하여 장례절차를 잘 챙기지 못할 뿐만 아니라 장례절차에 소요되는 여러 가지 물품을 비싼 비용으로 구입하게 되며, 특히 핵가족화로 인해 자녀 수가 감소하여 상주들의 숫자가 적어 장례절차를 치르는데 많은 어려움을 겪고 있는 실정이다. 종래의 장례 서비스 시스템은 장례 서비스 대행업체가 고객들을 대상으로 회원 유치하여 매월 회비를 받아 운영하고, 회원으로부터 관혼상제 서비스 요청에 따라 장례 서비스 제공업체에 장례 서비스를 요청하여 관혼상제에 관련된 용역 서비스를 대행함에 의해 장례 서비스가 기본적으로 이루어지도록 하고 있다. 예를 들면, 회원이 매월 일정금액을 일정기간 동안 상조회사에 회비로 납부하는 상태에서 회원의 가족 중 한 명이 사망하게 되는 경우, 회원은 상조회사에 장례 서비스를 요청하고, 이 요청에 따라 상조회사는 기설정된 계약 내용에 따라 장례 서비스 제공업체에 장례 서비스를 제공할 것을 요청하고, 상기 장례 서비스 제공업체는 요청된 장례 서비스에 따라 해당 회원에게 장례절차를 진행하고, 상기 상조회사로부터 장례 서비스에 대한 비용을 지급받게 된다. 이러한 장례 서비스 시스템의 중소업체 규모의 상조회사들이 난립하고 있어 신뢰성이 저하되고, 그 중 일부 회사는 온라인을 통해 선불 할부식으로 월납 회원을 모집하고 있는데, 회원이 납부한 회비에 대한 지급 보장이 없기 때문에 상조회사의 파산 또는 고의로 부도를 낸다거나 회원이 중도 해지할 경우 납부를 회비를 환급받지 못하는 경우가 있고, 장례서비스의 질(質)이 보장되지 않는 등 문제점이 많았다.  상술한 종래의 문제점을 해결하기 위해 대한민국등록특허 제10-1228134호인 '인터넷 기반의 장례 서비스 사전 제시형 후불식 장례 서비스 시스템'이 개시되어 있으며, 그 시스템을 간략하게 설명하면 고객으로부터 장례 서비스 가입 요청시, 고객의 상황에 맞는 장례 상품 선택 및 회원 가입 절차를 수행할 수 있도록 제어하고, 고객의 정보만으로 회원 자격이 부여된 고객의 클라이언트부로부터 장례 서비스 요청시, 회원이 기선택한 장례 상품의 목록에 대한 장례 서비스정보를 장례 담당자 단말기로 전송하여 장례 서비스의 제공을 요청하는 장례 서비스 운영부와 고객으로부터 장례 서비스 가입 요청시, 고객의 상황에 맞는 장례 서비스를 선택할 수 있도록 장례 상품에 대한 비교 정보를 목록별로 분류한 장례 상품 선택 인터페이스를 고객의 클라이언트부로 전송하는 장례 상품 선택부와, 고객의 클라이언트부를 통해 입력된 고객정보를 등록하여 회원 가입처리하고, 고객의 정보를 확인하여, 회원 자격을 부여하는 회원 관리부와, 회원에게 장례 서비스 제공의 종료시, 장례 상품에 대한 결제를 후불식으로 정산하여 고객의 클라이언트부로 정산된 장례비의 지급을 요청하는 장례비용 정산부를 포함하는 구성으로 이루어져 있다. 하여, 장례 서비스를 사전에 제시할 수 있도록 하여 고객의 상황에 맞는 장례 상품을 용이하게 선택할 수 있도록 하고, 고객이 정보를 입력하면 고객 정보를 검토 후 고객에게 회원 자격을 부여하며, 장례 행사 발생시, 장례 서비스 제공에 대한 장례비용은 후불식으로 정산할 수 있도록 하여 고객의 편의성을 향상시킬 수 있다는 장점이 있었다. 그러나, 이러한 종래기술은 몇가지 현실적인 문제점을 안고 있는데 그 문제점이란 고객이 장례 서비스 제공서버에 접속하여 장례에 필요한 상품을 선택할 수 있도록 하였으나, 실제 상을 당한 고객이 이러한 상품을 선택하거나 선택한다고 하더라도 회원가입을 위해 자신의 개인정보를 회원관리부에 접속하여 회원가입을 할만한 심적상황이 아닌 상태이기에 그 효율성이 떨어진다는 문제점이 있었다. ",
#   "pdf_open": "null",
#   "pdf_register": "null",
#   "pdf_rewrite_register": "null"
# }

# %% [markdown]
# ## 청구항1, 나머지 청구항, 요약 json 파일 만들기

# %%
import fitz
import json
import re
import requests
import os

def download_pdf(url, filename):
    response = requests.get(url)
    with open(filename, 'wb') as f:
        f.write(response.content)

def extract_content(pdf_path):
    doc = fitz.open(pdf_path)
    content = {}
    current_section = None
    section_content = ""

    for page in doc:
        blocks = page.get_text("dict")["blocks"]
        for block in blocks:
            if block['type'] == 0:  # 텍스트 블록
                for line in block["lines"]:
                    for span in line["spans"]:
                        is_italic = span['flags'] & 2**3 > 0  # 이탤릭 플래그 확인
                        text = span['text'].strip()
                        
                        if is_italic and text:  # 기울어진 텍스트를 새로운 섹션의 시작으로 간주
                            if current_section:
                                content[current_section] = section_content.strip()
                            current_section = text
                            section_content = ""
                        elif current_section:
                            section_content += text + " "

    # 마지막 섹션 처리
    if current_section:
        content[current_section] = section_content.strip()

    # 청구항과 요약 추출
    claims = {k: v for k, v in content.items() if '청구항' in k}
    summary = content.get('요약', '')

    return {
        "청구항": claims,
        "요약": summary
    }

def process_patents(input_file, output_file):
    with open(input_file, 'r') as f:
        patent_data = json.load(f)

    new_patent_data = {}

    for patent_number, pdf_url in patent_data.items():
        print(f"Processing patent number: {patent_number}")
        pdf_filename = f"{patent_number}.pdf"
        
        try:
            download_pdf(pdf_url, pdf_filename)
            content = extract_content(pdf_filename)
            new_patent_data[patent_number] = content
        except Exception as e:
            print(f"Error processing {patent_number}: {str(e)}")
        finally:
            if os.path.exists(pdf_filename):
                os.remove(pdf_filename)

    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(new_patent_data, f, ensure_ascii=False, indent=4)

    print(f"Processed data saved to {output_file}")

if __name__ == "__main__":
    input_file = '/home/user/hjkim/contextual/pdf_register_data(1-20,000).json'
    output_file = '/home/user/hjkim/contextual/processed_patent_data(1-20,000).json'
    process_patents(input_file, output_file)
# Out:
# Processing patent number: 1020170035102
# Processing patent number: 1020170035108
# Processing patent number: 1020170035116
# Processing patent number: 1020170035118
# Processing patent number: 1020170035122
# Processing patent number: 1020170035125
# Processing patent number: 1020170035126
# Processing patent number: 1020170035127
# Processing patent number: 1020170035129
# Processing patent number: 1020170035130
# Processing patent number: 1020170035133
# Processing patent number: 1020170035136
# Processing patent number: 1020170035137
# Processing patent number: 1020170035140
# Processing patent number: 1020170035142
# Processing patent number: 1020170035144
# Processing patent number: 1020170035145
# Processing patent number: 1020170035146
# Processing patent number: 1020170035156
# Processing patent number: 1020170035164
# Processing patent number: 1020170035169
# Processing patent number: 1020170035171
# Processing patent number: 1020170035175
# Processing patent number: 1020170035186
# Processing patent number: 1020170035187
# Processing patent number: 1020170035189
# Processing patent number: 1020170035191
# Processing patent number: 1020170035193
# Processing patent number: 1020170035194
# Processing patent number: 1020170035201
# Processing patent number: 1020170035204
# Processing patent number: 1020170035211
# Processing patent number: 1020170035215
# Processing patent number: 1020170035218
# Processing patent number: 1020170035222
# Processing patent number: 1020170035226
# Processing patent number: 1020170035233
# Processing patent number: 1020170035236
# Error processing 1020170035236: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# Processing patent number: 1020170035237
# Processing patent number: 1020170035241
# Processing patent number: 1020170035251
# Processing patent number: 1020170035264
# Processing patent number: 1020170035265
# Processing patent number: 1020170035275
# Processing patent number: 1020170035291
# Processing patent number: 1020170035293
# Processing patent number: 1020170035297
# Processing patent number: 1020170035299
# Processing patent number: 1020170035302
# Processing patent number: 1020170035305
# Processing patent number: 1020170035317
# Processing patent number: 1020170035318
# Processing patent number: 1020170035319
# Processing patent number: 1020170035324
# Processing patent number: 1020170035325
# Processing patent number: 1020170035333
# Processing patent number: 1020170035335
# Processing patent number: 1020170035346
# Processing patent number: 1020170035348
# Processing patent number: 1020170035353
# Processing patent number: 1020170035360
# Processing patent number: 1020170035362
# Processing patent number: 1020170035363
# Processing patent number: 1020170035364
# Processing patent number: 1020170035365
# Processing patent number: 1020170035104
# Processing patent number: 1020170035115
# Processing patent number: 1020170035123
# Processing patent number: 1020170035135
# Processing patent number: 1020170035152
# Processing patent number: 1020170035172
# Processing patent number: 1020170035173
# Processing patent number: 1020170035178
# Processing patent number: 1020170035200
# Processing patent number: 1020170035206
# Processing patent number: 1020170035208
# Processing patent number: 1020170035209
# Processing patent number: 1020170035212
# Processing patent number: 1020170035217
# Processing patent number: 1020170035219
# Processing patent number: 1020170035221
# Processing patent number: 1020170035224
# Processing patent number: 1020170035235
# Processing patent number: 1020170035247
# Processing patent number: 1020170035254
# Processing patent number: 1020170035255
# Processing patent number: 1020170035259
# Processing patent number: 1020170035286
# Processing patent number: 1020170035290
# Processing patent number: 1020170035307
# Processing patent number: 1020170035320
# Processing patent number: 1020170035321
# Processing patent number: 1020170035327
# Processing patent number: 1020170035340
# Processing patent number: 1020170035345
# Processing patent number: 1020170035349
# Processing patent number: 1020170035350
# Processing patent number: 1020170035352
# Processing patent number: 1020170035372
# Processing patent number: 1020170035378
# Processing patent number: 1020170035386
# Processing patent number: 1020170035388
# Processing patent number: 1020170035390
# Processing patent number: 1020170035392
# Processing patent number: 1020170035395
# Processing patent number: 1020170035412
# Processing patent number: 1020170035420
# Processing patent number: 1020170035422
# Processing patent number: 1020170035427
# Processing patent number: 1020170035433
# Processing patent number: 1020170035440
# Processing patent number: 1020170035446
# Processing patent number: 1020170035448
# Processing patent number: 1020170035452
# Processing patent number: 1020170035455
# Processing patent number: 1020170035458
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 76
#      74 input_file = '/home/user/hjkim/contextual/pdf_register_data(1-20,000).json'
#      75 output_file = '/home/user/hjkim/contextual/processed_patent_data(1-20,000).json'
# ---> 76 process_patents(input_file, output_file)
#
# Cell In[5], line 60, in process_patents(input_file, output_file)
#      58 try:
#      59     download_pdf(pdf_url, pdf_filename)
# ---> 60     content = extract_content(pdf_filename)
#      61     new_patent_data[patent_number] = content
#      62 except Exception as e:
#
# Cell In[5], line 19, in extract_content(pdf_path)
#      16 section_content = ""
#      18 for page in doc:
# ---> 19     blocks = page.get_text("dict")["blocks"]
#      20     for block in blocks:
#      21         if block['type'] == 0:  # 텍스트 블록
#
# File ~/anaconda3/envs/hjkim/lib/python3.10/site-packages/pymupdf/utils.py:975, in get_text(page, option, clip, flags, textpage, sort, delimiters, tolerance)
#     973 #pymupdf.exception_info()
#     974 if tp is None:
# --> 975     tp = page.get_textpage(clip=clip, flags=flags)
#     976 elif getattr(tp, "parent") != page:
#     977     raise ValueError("not a textpage of this page")
#
# File ~/anaconda3/envs/hjkim/lib/python3.10/site-packages/pymupdf/__init__.py:9429, in Page.get_textpage(self, clip, flags, matrix)
#    9427     self.set_rotation(0)
#    9428 try:
# -> 9429     textpage = self._get_textpage(clip, flags=flags, matrix=matrix)
#    9430 finally:
#    9431     if old_rotation != 0:
#
# File ~/anaconda3/envs/hjkim/lib/python3.10/site-packages/pymupdf/__init__.py:7954, in Page._get_textpage(self, clip, flags, matrix)
#    7952 def _get_textpage(self, clip=None, flags=0, matrix=None):
#    7953     if g_use_extra:
# -> 7954         ll_tpage = extra.page_get_textpage(self.this, clip, flags, matrix)
#    7955         tpage = mupdf.FzStextPage(ll_tpage)
#    7956         return tpage
#
# File ~/anaconda3/envs/hjkim/lib/python3.10/site-packages/pymupdf/extra.py:192, in page_get_textpage(_self, clip, flags, matrix)
#     191 def page_get_textpage(_self, clip, flags, matrix):
# --> 192     return _extra.page_get_textpage(_self, clip, flags, matrix)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 실험

# %%
#  Test(PDF 두개만 먼저 출력)
import fitz
import json
import re
import requests
import os

def download_pdf(url, filename):
    response = requests.get(url)
    with open(filename, 'wb') as f:
        f.write(response.content)

def extract_content(pdf_path):
    doc = fitz.open(pdf_path)
    content = {}
    current_section = None
    section_content = ""

    for page in doc:
        blocks = page.get_text("dict")["blocks"]
        for block in blocks:
            if block['type'] == 0:  # 텍스트 블록
                for line in block["lines"]:
                    for span in line["spans"]:
                        is_italic = span['flags'] & 2**3 > 0  # 이탤릭 플래그 확인
                        text = span['text'].strip()
                        
                        if is_italic and text:  # 기울어진 텍스트를 새로운 섹션의 시작으로 간주
                            if current_section:
                                content[current_section] = section_content.strip()
                            current_section = text
                            section_content = ""
                        elif current_section:
                            section_content += text + " "

    # 마지막 섹션 처리
    if current_section:
        content[current_section] = section_content.strip()

    # 청구항과 요약 추출
    claims = {k: v for k, v in content.items() if '청구항' in k}
    summary = content.get('요약', '')

    return {
        "청구항": claims,
        "요약": summary
    }

def process_sample_patents(input_file, sample_count=2):
    with open(input_file, 'r') as f:
        patent_data = json.load(f)

    new_patent_data = {}
    count = 0

    for patent_number, pdf_url in patent_data.items():
        if count >= sample_count:
            break

        print(f"Processing patent number: {patent_number}")
        pdf_filename = f"{patent_number}.pdf"
        
        try:
            download_pdf(pdf_url, pdf_filename)
            content = extract_content(pdf_filename)
            new_patent_data[patent_number] = content
            print(f"Extracted content for patent {patent_number}:\n", content)
            count += 1
        except Exception as e:
            print(f"Error processing {patent_number}: {str(e)}")
        finally:
            if os.path.exists(pdf_filename):
                os.remove(pdf_filename)

    print("Sample processing complete.")

# 실행 코드
input_file = '/home/user/hjkim/contextual/pdf_register_data(1-20,000).json'
process_sample_patents(input_file)
# Out:
# Processing patent number: 1020170035102
# Extracted content for patent 1020170035102:
#  {'청구항': {}, '요약': ''}
# Processing patent number: 1020170035108
# Extracted content for patent 1020170035108:
#  {'청구항': {}, '요약': ''}
# Sample processing complete.

# %%
import fitz
import json
import requests
import os
import re

def download_pdf(url, filename):
    response = requests.get(url)
    with open(filename, 'wb') as f:
        f.write(response.content)

def extract_content(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()

    content = {
        'full_text': full_text,
        '청구범위': '',
        '요약': ''
    }

    # 청구범위 추출
    claims_match = re.search(r'청구범위(.*?)(?:도면|$)', full_text, re.DOTALL)
    if claims_match:
        content['청구범위'] = claims_match.group(1).strip()
    
    # 요약 추출
    summary_match = re.search(r'\(\d+\)\s*요\s*약(.*?)(?:\(뒷면에 계속\)|$)', full_text, re.DOTALL)
    if summary_match:
        content['요약'] = summary_match.group(1).strip()
    
    return content

# JSON 파일에서 특허 데이터 로드
input_file = '/home/user/hjkim/contextual/pdf_register_data(1-20,000).json'
with open(input_file, 'r') as f:
    patent_data = json.load(f)

# 처음 한 개의 PDF만 처리
for patent_number, pdf_url in list(patent_data.items())[:1]:
    pdf_filename = f"{patent_number}.pdf"
    print(f"\nProcessing patent number: {patent_number}")
    
    try:
        download_pdf(pdf_url, pdf_filename)
        content = extract_content(pdf_filename)
        
        print("\n청구범위:")
        print(content['청구범위'] if content['청구범위'] else 'Not found')
        
        print("\n요약:")
        print(content['요약'] if content['요약'] else 'Not found')
        
    except Exception as e:
        print(f"Error processing {patent_number}: {str(e)}")
    finally:
        if os.path.exists(pdf_filename):
            os.remove(pdf_filename)

print("Processing complete.")
# Out:
# Processing patent number: 1020170035102
#
# 청구범위:
# 청구항 1
# 소정의 형상과 재질로 되어서 일정길이를 가지며 하단부가 지면에 고정되는 한 개 이상의 고정기둥(10);과
# 중앙부에 소정크기의 구멍인 빈공간이 형성 된 고정부 원형 판(21)에서 빈 공간인 구멍의 외측 가장자리둘레 부
# 분을 따라 일정한 간격으로 보빈(bobbin)(221)에 코일(coil)(222)이 감겨진 다수의 권선체(22)들이 배열된 코일
# 고정판(20);과,
# 소정의 굵기와 재질과 형상으로 일정 길이를 가지며 내부가 비어 있거나 채워져 있는 풍력기둥(31)과, 풍력기둥
# (31)의 하단에는 고정기둥(10)의 상측에 그 하단이 고정되도록 하는 소정의 길이를 가지며 그 단면의
# 크기(굵기)가 상기 풍력기둥(31)의 단면크기(굵기) 보다가 일정크기만큼 더 작은 진동막대(32)가 달린 진동기둥
# (30);과
# 원형으로 된 진동부 원형 판(41)의 가장자리 근처의 둘레를 따라 원형의 영구자석(42)이 배치된 원형의 진동자
# 석판(40);으로 이루어져서,
# 원형의 코일고정판(20)은 그 외측둘레가 고정기둥(10)의 상부외측둘레에서 위쪽으로 돌출된 지지부재(23)에 지
# 지가 되어 고정이 되는 상태의 수평방향으로 배치가 되며 원형의 진동자석판(40)은 원형의 코일고정판(20)과 일
# 정거리 이격된 근접하는 위치에서 그 중심이 진동기둥(30)의 막대(32)에 결박되어 구속되는 상태의 수평방향으
# 로 배치가 되어 진동기둥(30)이 바람에 의하여 흔들리면서 진동을 함에 따라 진동자석판(40)은 그 중심이 진동
# 기둥(30) 아래쪽의 진동막대(32)에 결박되어 진동막대(32)와 함께 수평왕복의 진동운동을 하게 되어 고정기둥의
# 상측에서 진동자석판(40)과 가깝게 근접하여 고정된 코일고정판(20)의 권선체(22)에 감긴 코일(coil)(222)에는
# 영구자석(42)이 가깝게 근접하여 연속적으로 수평왕복의 진동운동을 하게 되고 그에 따라 코일(coil)(222)에서
# 는 연속적인 자기장의 변화와 함께 유도전기가 발생되도록 하는 것을 특징으로 하는 풍력진동발전기.
# 청구항 2
# 청구항 1에 있어서,
# 원형의 진동자석판(40)과 원형의 코일고정판(20)은 각각 한 개 이상 여러 개를 구비하여 고정기둥(10)의 상측인
# 진동막대(32)부분에서 원형의 진동자석판(40)들과 원형의 코일고정판(20)들을 수직방향의 일정간격으로 하나씩
# 하나씩 교대로 번갈아가면서 서로 가깝게 인접하는 수평의 방향이 되도록 배치되는 것을 특징으로 하는 풍력진
# 동발전기.
# 청구항 3
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)은 위쪽으로 갈수록 단면이 점점 더 커지는 거꾸로 된 원추형의 모양
# 으로 구비가 되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 4
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)의 상단부에는 소정의 무게를 가지는 무게장치(33)가 별도로 구비된
# 것을 특징으로 하는 풍력진동발전기.
# 청구항 5
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)에는 그 표면에 소정의 형상으로 된 다수의 돌기(311)들이 형성된 것
# 을 특징으로 하는 풍력진동발전기.
# 등록특허 10-1910526
# - 3 -
# 청구항 6
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)은 탄소섬유(carbon fiber) 또는 유리섬유(glass fiber) 또는 아라미
# 드섬유(aramid fiber)나 초고분자폴리에틸렌(UHMWPE)섬유 중의 어느 하나에 에폭시 등의 수지(樹脂, resin)제품
# 을 함침(含浸, impregnation)시킨 섬유강화복합재료의 재질로 형성이 되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 7
# 청구항 1에 있어서,
# 진동기둥(30)의 하측이 되는 막대(32)는 강연선(鋼撚線, strand)으로 되거나 또는 탄소섬유(carbon fiber)나 유
# 리섬유(glass fiber)나 아라미드섬유(aramid fiber)나 초고분자폴리에틸렌(UHMWPE)섬유 중의 어느 하나에 에폭
# 시 등의 수지(樹脂, resin)제품을 함침(含浸, impregnation)시킨 섬유강화복합재료의 재질로 되는 것을 특징으
# 로 하는 풍력진동발전기.
# 청구항 8
# 청구항 1에 있어서,
# 권선체(22)에 감겨진 코일(coil)(222)의 중심축이 고정부 원형 판(21)의 중앙부에 형성된 빈 공간인 구멍의 외
# 측가장자리둘레 근처의 소정위치에서부터 수평의 방향으로 원형 판(21)의 외측바깥쪽으로 향하게 되는 방사선모
# 양으로 다수가 구비되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 9
# 청구항 1에 있어서,
# 권선체(22)에 감겨진 코일(coil)(222)의 중심축이 수직인 상태에서 권선체(22)의 일 측 끝단은 고정부 원형 판
# (21)의 위쪽으로 향하고 다른 일 측의 끝단은 고정부 원형 판(21)의 아래쪽으로 향하면서 그 중간은 고정부 원
# 형 판(21)  중앙부의 빈공간인 구멍의 외측가장자리둘레 근처의 소정위치에 있게 되는 상태로 고정부 원형 판
# (21) 중앙부의 빈공간인 구멍의 외측가장자리둘레 근처를 따라 일정한 간격으로 다수의 권선체(22)가 구비되는
# 것을 특징으로 하는 풍력진동발전기.
# 발명의 설명
# 기 술 분 야
# 본 발명은 풍력진동발전기에 관한 것으로서, 더욱 상세하게는 무게가 가벼운 구조로 되어 바람에 의하여 잘 흔
# [0001]
# 들리는 진동기둥의 아래쪽 부분에 영구자석으로 된 다수의 진동자석판들과 여러 겹의 코일들이 다양한 형태로
# 감겨진 권선체들이 구비된 다수의 코일고정판들을 수직방향의 일정간격으로 하나씩 하나씩 번갈아가면서 교대하
# 는 상태가 되도록 배치를 하되, 진동자석판들은 진동기둥의 아래쪽부분에서 소정의 길이를 가지도록 구비가 된
# 진동막대에 그 중심이 결박되어 구속이 되는 수평의 상태로 수직방향의 일정간격으로 배치를 하게 되고, 코일고
# 정판들은 수평의 상태에서 그 중심부에는 구멍이 뚫려있어서 빈 공간으로 구비가 되어 하단이 땅바닥의 지면에
# 고정된 고정기둥의 상측둘레에서 위쪽으로 돌출이 된 지지부재에 그 외측둘레가 지지되도록 하여 수직방향의 일
# 정간격이 되도록 수평방향으로 배치를 하여 구비를 하게 된다.
# 상기에서 진동기둥의 아래쪽에 구비되는 진동막대의 하단을 고정기둥의 상측에서 고정을 시키되, 고정기둥 상측
# [0002]
# 의 지지부재에 그 외측둘레가 고정된 코일고정판의 중앙부에서 빈 공간으로 뚫려진 구멍 속으로 진동기둥 아래
# 쪽의 진동막대가 삽입되도록 하여 각각의 코일고정판들은 수직방향으로는 진동막대의 소정길이부분과 중복하는
# 위치에 있게 되지만 수평방향으로는 중앙부 빈 공간의 중심에 진동막대가 있게 되어서 결국 진동막대와 코일고
# 정판은 전후좌우의 모든 수평방향으로 일정거리 만큼이 이격되는 상태로서 진동기둥뿐만 아니라 진동막대의 어
# 느 한부분과도 서로 맞닿거나 접촉이 되지를 않아서 상호간에는 일정거리만큼이 이격되는 공간이 있게 되는 상
# 태가 된다.
# 따라서 코일고정판은 오로지 하단이 땅바닥의 지면에 고정된 고정기둥의 상부 외측둘레에서 위쪽으로 돌출된 지
# [0003]
# 지부재에 그 외측둘레가 지지되어서, 진동막대뿐만 아니라 진동기둥과는 전혀 무관한 상태가 되어 바람에 의하
# 등록특허 10-1910526
# - 4 -
# 여 흔들리면서 진동이나 유동을 하지 않게 되는 반면, 진동자석판들은 수평방향의 상태에서 그 중심이 진동기둥
# 아래쪽의 진동막대에 구속이 되어 결박되는 상태로 수직방향의 일정간격으로 코일고정판들과는 하나씩 하나씩
# 교대로 번갈아 가면서 배치가 되어 진동기둥이 바람에 의하여 흔들리면서 진동을 함에 따라 진동자석판들은 진
# 동막대와 함께 전후좌우의 모든 수평방향으로 흔들리면서 진동을 하게 된다.
# 이때의 진동자석판들은 고정기둥의 상측에서 바람에 의하여 흔들리지 않도록 고정된 다수 코일고정판들의 사이
# [0004]
# 사이마다에 구비가 된 것으로서 결과적으로 코일고정판들에 구비가 된 권선체 코일들의 아래와 위쪽에서는 진동
# 기둥의 바람에 의한 진동으로 인하여 진동자석판의 영구자석들이 전후좌우 수평의 모든 방향으로 연속하여 흔들
# 리는 수평왕복의 진동을 하게 되고 그에 따라서 코일고정판 권선체들의 코일에서는 연속적인 자기장의 변화가
# 유도되면서 전기가 발생되도록 하고자 하는 풍력진동발전기에 관한 것이다.
# 배 경 기 술
# 풍력발전은 바람에 의한 풍력에너지를 전기에너지로 전환하는 것을 총칭한 것으로서 지금까지 공지되어온 대부
# [0005]
# 분의 방법들은 바람개비의 원리로서 바람에 의한 회전날개의 회전동력을 회전식전기발전기로서 전기를 생산하는
# 형식이 전부일 정도로 거의 대부분인바 회전식날개의 형태나 회전방법, 크기, 발전기의 용량 등 천차만별의 각
# 종 사양들이 공지되어 있는 바로서 크게 구분을 하자면 회전날개와 발전기의 회전축이 지면과 평행한 수평풍차
# 방식과 그 반대인 수직풍차방식이 있다.
# 수직풍차방식은 실용적인 상업목적의 용도가 되는 일정크기 이상의 출력전기를 확보하기 위해서 회전날개가 아
# [0006]
# 주 커져야만 하는 관계로 지면에서부터 일정높이부분까지의 지면인근의 공간에서 수직축방향의 비교적 큰 회전
# 날개가 회전할 수 있도록 하는 넓은 공간이 확보되어야만 하며 효율 또한 그리 좋지를 못해서 실용적인 상업목
# 적의 용도로는 거의 적용이 되지를 못하는 실정으로서 단지 아주 작은 소규모로 된 수직축방향의 회전날개장치
# 사양들이 일부 제시가 되고는 있다.
# 수평풍차방식은 비교적 높은 기둥위에 수평방향의 회전축을 가지는 날개와 기어장치와 회전식발전기를 구비한
# [0007]
# 것으로서 그 용량에 따라 아주 작은 소규모부터 대규모의 장치들까지 다양하지만 실용적인 상업목적의 용도가
# 되기 위해서는 어느 정도이상의 크기가 확보되는 대규모가 되거나 또는 대규모에 가까운 크기가 되어야만 하는
# 바 이와 같은 대규모에 가까운 크기 이상의 수평풍차방식이 현재까지 구현되고 있는 풍력발전의 거의 대부분이
# 다.
# 상기에서와 같은 실용적인 상업목적의 용도가 되는 대규모에 가까운 크기 이상의 수평풍차방식에서는 날개를 비
# [0008]
# 롯한 주변 장치들의 무게가 상당히 무거우면서도 전체적으로는 중후한 구조이기 때문에 약한 바람에서는 전혀
# 작동을 하지 못하며 또한 너무 강한 바람이 불어올 때는 강한 바람에 비하여 날개와 발전장치들을 비롯한 전체
# 적인 기계장치들이 상대적으로 오히려 너무 가볍고도 약한 구조가 되기에 작동을 멈추어야만 하는 것으로서 일
# 반적으로는 풍속이 4 m/sec이상이 되어야만 작동을 하기 시작하고 13 m/sec정도에서 100%의 효율이 나오며 25
# m/sec이상의 바람이 불면 발전기가 자동으로 작동을 멈추도록 하는 것이 아주 일반적인 정설로 되어 있는 실정
# 으로서 세계의 각 지역마다 천차만별이기 하지만 일 년 사계절 중에서 결국 발전이 가능한 풍속이 유지되는 시
# 간의 길이의 그리 길지를 못하다.
# 특히나 여건이 아주 좋은 곳이라 하더라도 일 년 중에서 풍속이 4 m/sec이상이 되는 시간은 50%를 넘지 못하고
# [0009]
# 더욱이 우리나라는 바람이 그리 많지도 않으면서 태풍과 같은 강풍들은 수시로 불어오는 지형적인 요인들로 인
# 하여 상기와 같은 풍력발전에 적합한 적정풍속이 유지되는 시간대는 일 년 중에서도 겨우 20～30%정도 밖에 되
# 지를 못하는 것으로 알려져 있다.
# 또한 상기에서와 같은 실용적인 상업목적의 용도가 되는 대규모에 가까운 크기 이상의 수평풍차방식에서는 아주
# [0010]
# 높은 기둥위에서 25 m/sec까지의 강한 바람에도 유효하게 작동을 하여야만 할뿐만 아니라 그 이상의 풍속에 있
# 어서는 높은 기둥위에 매달린 구조의 가늘고도 긴 날개와 각종 기계장치들이 높은 기둥과 함께 안전하게 견뎌야
# 하는 구조가 되어야만 하다가보니 어쩔 수 없이 날개와 기둥과 발전기를 비롯한 기계장치들은 크고, 무겁고, 중
# 후해질 수밖에 없는 관계로 아주 큰 고가의 비용이 소요됨으로 인하여 대규모의 자금을 동원하지 않고서는 쉽게
# 접근을 할 수가 없어서 대부분의 사람들에게는 풍력발전이라는 분야자체가 쉽게 접근할 수가 없는 아주 어렵고
# 도 힘든 분야로 인식이 되어 있는 실정이며, 또한 전반적으로도 상기에서와 같이 아주 고가의 비용이 소요됨으
# 로 인하여 대규모의 자금을 동원해야안 하는 것에 비하여서는 생산되는 전력이 그리 크지를 않아서 효율이 상당
# 히 낮은 것으로 인식들이 되어 있고 특히나 바람이 조금만 강하게 불어도 바람개비의 날개가 쉽게 손상이 되거
# 나 부러지는 등의 상당한 문제점들이 노출되고 있는 실정이다.
# 등록특허 10-1910526
# - 5 -
# 뿐만 아니라 바람을 받아서 회전을 하는 날개가 회전을 잘 하기 위해서는 반드시 최대한 가늘고도 길면서 가벼
# [0011]
# 워야만 한다는 절대적인 명제로 인하여 특히나 날개의 제작과 유지관리에 많은 비용과 노력이 요구되며 잦은 손
# 상과 파손과 함께 잘 부러지는 등의 문제들뿐만 아니라 회전할 때의 소음 또한 상당히 크고 또한 아주 큰 날개
# 가 허공에 매달려서 노출이 된 채로 빠르게 회전을 함으로 인하여 근처에서 지켜보는 사람들에게는 상당한 불안
# 감을 주게 되며 또한 날개의 잦은 파손과 부러질 때의 낙하에 의한 위험성들로 인하여 주거지역이나 공공시설
# 등 사람들의 통상적인 활동영역과는 상당히 멀리 떨어져 있어야만 하는 등의 문제점들이 상존하고 있는 실정이
# 다.
# 본 발명의 배경이 되는 기술로는 특허등록 제0993767호 "승·하강 수직 풍력발전기"(특허문헌 1)이 있다. 상기
# [0012]
# 배경기술에서는 '지면에 고정대 볼트(130)로 고정대(120)가 고정되며, 상기 고정대(120)에 상측기둥(100)과 하
# 측기둥(110)이 구비되는 본체부(10); 상기 상측기둥(100)에 상측 회전관(200)과, 코일관(220)과, 하측 회전관
# (210)이 회전관 볼트(221)로 결합되는 회전부(20);  상기 상측기둥(100)과 하측기둥(110)  사이에 유압실린더
# (300)가 구비되는 승·하강부(30);  상기 하측기둥(110)  중앙에 밴드형식의 클램프(420)가 볼트(430)로
# 고정되고, 클램프(420)에 연결관(410)이 결합되며, 상기 연결관(410) 일측에 제어케이스(400)가 형성되어, 유압
# 실린더(300)의 작동과 회전부(20)의 감속작동을 제어해주는 제어부(40); 를 포함하여 구성한 것을 특징으로 하
# 는 승·하강 수직 풍력발전기'를 제안한다.
# 그러나 상기 배경기술 역시 날개를 구성하여 회전시키는 것으로 회전으로 인한 소음 및 구성품들의 유지관리가
# [0013]
# 어려운 문제점이 있었다.
# 선행기술문헌
# 특허문헌
# (특허문헌 0001) 특허등록 제0993767호 "승·하강 수직 풍력발전기"
# [0014]
# 발명의 내용
# 해결하려는 과제
# 본 발명은 상기와 같은 문제점을 해결하기 위한 것으로, 무게가 아주 가벼운 재질로 된 진동기둥이 바람에 의하
# [0015]
# 여 잘 흔들리도록 하여 이와 함께 여러 겹의 코일이 감긴 다수의 권선체들이 구비된 원형의 코일고정판과 영구
# 자석이 구비된 원형의 진동자석판들을 이용하여 바람에 의하여 흔들리는 진동기둥의 진동에너지를 전기에너지로
# 전환하고자 하는 것으로서 좀 더 상세하게는 상기 진동기둥의 아래쪽에 구비되는 소정길이의 진동막대부분에다
# 가 원형의 영구자석이 구비된 다수의 진동자석판들을 수평방향의 상태에서 그 중심이 진동막대에 결박되어 구속
# 이 되도록 하여 수직방향의 일정간격으로 배치를 하게 되고, 코일이 감겨진 다수의 권선체들이 각종의 다양한
# 형태로 구비가 되는 다수의 코일고정판들은 지면에 하단이 고정된 고정기둥 상부의 외측둘레에서 위쪽으로 돌출
# 된 지지부재에 그 외측둘레가 고정되는 상태로 수직방향의 일정간격이 되는 수평의 상태로 배치를 하게 된다.
# 또한 상기의 코일고정판들은 수평방향의 상태에서 그 중앙부에는 구멍이 뚫려있어서 빈공간이 형성되어 진동막
# [0016]
# 대의 중간이 그 구멍의 중심으로 삽입이 된 상태에서 진동막대의 하단은 상기 고정기둥의 위쪽에서 고정이 되도
# 록 하게 된다.
# 따라서 상기 고정기둥 상부의 소정공간은 코일고정판들과 함께 진동자석판 및 진동막대가 수직방향으로 중첩하
# [0017]
# 여 배치가 되는 바로서, 이때 진동자석판과 코일고정판은 수직방향의 일정간격으로 하나씩 하나씩 번갈아가면서
# 순차적으로 교대하는 상태가 되게 하고, 또한 진동막대는 코일고정판의 중앙부 빈 공간의 중심에 삽입되는 상태
# 가 되어서 각각의 코일고정판들은 진동기둥뿐만 아니라 진동막대의 어느 한부분과도 서로 맞닿거나 접촉이 되지
# 를 않으면서 고정기둥 상부의 외측둘레에서 위쪽으로 돌출된 지지부재에 그 외측둘레가 고정되는 상태가 된다.
#  따라서 진동막대와 코일고정판은 수평방향으로 일정거리 만큼 이격이 되는 상태로 상호간에는 소정의 공간이
# [0018]
# 있게 되는 반면 진동자석판은 그 중심이 진동막대에 구속되어 결박이 되는 상태에서 진동자석판과 코일고정판이
# 수직방향의 일정간격으로 하나씩 하나씩 번갈아가면서 순차적으로 교대를 하는 상태가 된다.
# 상기에서와 같이 구비가 된 상태에서 된 진동기둥이 바람에 의하여 흔들리게 되면 진동기둥의 아래쪽이 되는 진
# [0019]
# 동막대 또한 전후좌우의 모든 수평방향으로 흔들리면서 진동을 하게 되고 그에 따라 중심이 진동막대에 구속되
# 등록특허 10-1910526
# - 6 -
# 어 결박이 된 진동자석판들도 함께 전후좌우의 모든 수평방향으로 진동막대와 함께 흔들리면서 고정기둥 상측의
# 지지부재에 의하여 그 외측 둘레가 고정된 코일고정판들의 사이사이마다에서 수평왕복의 진동운동을 하게 된다.
# 따라서 결과적으로는 진동자석판들의 영구자석들이 코일고정판들에 고정된 각 권선체 코일들의 아래위에서 바람
# [0020]
# 에 의한 연속적인 수평왕복의 진동운동을 하게 되는 것으로서 이로 인하여 각 권선체들의 코일에는 자기장의 변
# 화가 유도되고 그에 따라서 전기가 발생되도록 하게 된다.
# 상기에 있어서 진동기둥의 높이와 직경을 크게 하거나 또는 그 표면에다가 각종형상의 돌기들을 부착하여 구비
# [0021]
# 를 하는 등의 다양한 방법들로서 바람을 많이 받도록 하고 진동막대의 길이를 좀 더 길게 하여 수직방향의 일정
# 간격으로 하나씩 하나씩 번갈아가면서 순차적으로 교대를 하는 상태로 배치가 되는 진동자석판과 코일고정판의
# 숫자를 늘리거나 또는 전기적 용량을 크게 하는 등의 다양한 방법들로서 상당히 큰 용량의 전기에너지를 취득할
# 수가 있도록 하게 된다.
# 또한 상기에 있어서 진동기둥은 바람을 직접 받게 되는 상측의 풍력기둥과 그 아래쪽에서 소정의 길이를 가지며
# [0022]
# 단면의 크기(굵기)가 풍력기둥의 단면크기 보다가는 일정 크기(굵기)만큼 작은 진동막대로 구비가 되는 것으로
# 서 진동막대는 그 일 측이 풍력기둥의 하단에서 결착되어 고정이 되고 다른 일 측은 하단이 지면에 고정된 고정
# 기둥의 상측에 결착되어 고정이 되어서는 풍력기둥이 직접 바람을 받아서 흔들리게 되면 그 아래쪽의 진동막대
# 또한 전후좌우의 모든 수평방향으로 함께 흔들리면서 수평왕복의 진동운동을 원활히 할 수가 있는 구조가 되어
# 야만 하기에 그 재질의 인성이 아주 강하면서도 탄성이 풍부하여 특히나 아주 잘 휘어지면서도 빠르게 복원이
# 되는 탄소섬유(carbon fiber) 또는 유리섬유(glass fiber) 또는 아라미드섬유(aramid fiber)나 초고분자폴리에
# 틸렌(UHMWPE)섬유에 에폭시 등의 수지(樹脂,  resin)제품을 함침(含浸,  impregnation)시킨 섬유강화복합재료의
# 재질이거나 또는 가늘고 긴 PC강연선과 같은 재질들로 구비를 하게 된다.
# 상기와 같은 구조는 아주 약한 바람에서도 진동기둥은 끊임없이 흔들리게 될 뿐만 아니라 자연재해수준의 초강
# [0023]
# 력 태풍만 아니라면 아주 강한 강풍에서도 들판의 나무들처럼 항상 끊임없이 흔들리게 된다.
# 또한 상기와 같은 구조는 전반적으로 그 구성들이 아주 간단하면서도 특히나 무게가 아주 가벼워서 제작과 설치
# [0024]
# 가 쉽고도 용이하여 이에 소요되는 비용은 상기에서와 같은 실용적인 상업목적의 대규모에 가까운 크기 이상의
# 수평풍차방식에 의한 풍력발전기의 건설비용에 비하여서는 비교를 할 가치조차도 없을 만큼 저렴해지게 될 뿐만
# 아니라 자연재해수준의 초강력태풍이 아닌 이상 아주 약한 바람이든 상당히 강한 바람이든 어떠한 풍속의 영역
# 하에서도 항상 흔들리면서 전기를 생산할 수가 있는 되어 소요되는 비용과 생산되는 전력과의 상호관계적인 효
# 율이 아주 우수하여 다소의 관심만으로도 대부분의 사람들 누구나가 쉽게 접근할 수 있게 되는 보다 더 진보적
# 이면서도 실용적인 회전날개가 없는 풍력진동발전기를 제공하는데 그 목적이 있다.
# 또한 상기의 목적과 함께 날개가 없음으로 인하여 소음이 없게 되는 것은 물론이고 사람들에게 날개의 회전에
# [0025]
# 따라 위험해 보이는 불안감이나 날개가 파손되거나 부러져서 낙하하는 것들과 같은 위험성들을 모두 배제하기
# 때문에 상기구조에 의하여 사람들과는 아주 친숙하게 일반 가정주택의 앞마당,  주택인근의 산이나 유휴지,
# 공원, 야산, 들판, 공용도로의 주변 등 어디든 누구나가 쉽게 설치를 하여 발전을 할 수가 있게 되는 실용적인
# 회전날개가 없는 풍력진동발전기를 제공하는데 그 목적이 있다.
# 과제의 해결 수단
# 본 발명은 소정의 형상과 재질로 되어서 일정길이를 가지며 하단부가 지면에 고정되는 한 개 이상의 고정기둥
# [0026]
# (10);과 중앙부에 소정크기의 구멍인 빈공간이 형성 된 고정부 원형 판(21)에서 빈 공간인 구멍의 외측 가장자
# 리둘레 부분을 따라 일정한 간격으로 보빈(bobbin)(221)에 코일(222)이 감겨진 다수의 권선체(22)들이 배열된
# 코일고정판(20);과, 소정의 굵기와 재질과 형상으로 일정 길이를 가지며 내부가 비어 있거나 채워져 있는 풍력
# 기둥(31)과, 풍력기둥(31)의 하단에는 고정기둥(10)의 상측에 그 하단이 고정되도록 하는 소정의 길이를 가지며
# 그 단면의 크기(굵기)가 상기 풍력기둥(31)의 단면크기(굵기) 보다가 일정크기만큼 더 작은 진동막대(32)가 달
# 린 진동기둥(30);과 원형으로 된 진동부 원형 판(41)의 가장자리 근처의 둘레를 따라 원형의 영구자석(42)이 배
# 치된 원형의 진동자석판(40);으로 이루어져서, 원형의 코일고정판(20)은 그 외측둘레가 고정기둥(10)의 상부외
# 측둘레에서 위쪽으로 돌출된 지지부재(23)에 지지가 되어 고정이 되는 상태의 수평방향으로 배치가 되며 원형의
# 진동자석판(40)은 원형의 코일고정판(20)과 일정거리 이격된 근접하는 위치에서 그 중심이 진동기둥(30)의 막대
# (32)에 결박되어 구속되는 상태의 수평방향으로 배치가 되어 진동기둥(30)이 바람에 의하여 흔들리면서 진동을
# 함에 따라 진동자석판(40)은 그 중심이 진동기둥(30) 아래쪽의 진동막대(32)에 결박되어 진동막대(32)와 함께
# 수평왕복의 진동운동을 하게 되어 고정기둥의 상측에서 진동자석판(40)과 가깝게 근접하여 고정된 코일고정판
# 등록특허 10-1910526
# - 7 -
# (20)의 권선체(22)에 감긴 코일(222)에는 영구자석(42)이 가깝게 근접하여 연속적으로 수평왕복의 진동운동을
# 하게 되고 그에 따라 코일(222)에서는 연속적인 자기장의 변화와 함께 유도전기가 발생되도록 하는 것을 특징으
# 로 하는 풍력진동발전기를 제공하고자 한다.
# 또한, 원형의 진동자석판(40)과 원형의 코일고정판(20)은 각각 한 개 이상 여러 개를 구비하여 고정기둥(10)의
# [0027]
# 상측인 진동막대(32)부분에서 원형의 진동자석판(40)들과 원형의 코일고정판(20)들을 수직방향의 일정간격으로
# 하나씩 하나씩 교대로 번갈아가면서 서로 가깝게 인접하는 수평의 방향이 되도록 배치하게 되는 것을 특징으로
# 풍력진동발전기를 제공하고자 한다.
# 또한, 진동기둥(30)의 상측이 되는 풍력기둥(31)은 위쪽으로 갈수록 단면이 점점 더 커지는 거꾸로 된 원추형의
# [0028]
# 모양으로 구비가 되는 것을 특징으로 하는 풍력진동발전기를 제공하고자 한다.
# 또한, 진동기둥(30)의 상측이 되는 풍력기둥(31)의 상단부에는 소정의 무게를 가지는 무게장치(33)가 별도로 구
# [0029]
# 비된 것을 특징으로 하는 풍력진동발전기를 제공하고자 한다.
# 또한, 진동기둥(30)의 상측이 되는 풍력기둥(31)에는 그 표면에 소정의 형상으로 된 다수의 돌기(311)들이 형성
# [0030]
# 된 것을 특징으로 하는 풍력진동발전기를 제공하고자 한다.
# 또한, 진동기둥(30)의 상측이 되는 풍력기둥(31)은 탄소섬유(carbon fiber) 또는 유리섬유(glass fiber) 또는
# [0031]
# 아라미드섬유(aramid  fiber)나 초고분자폴리에틸렌(UHMWPE)섬유 중의 어느 하나에 에폭시 등의 수지(樹脂,
# resin)제품을 함침(含浸, impregnation)시킨 섬유강화복합재료의 재질로 형성이 되는 것을 특징으로 하는 풍력
# 진동발전기를 제공하고자 한다.
# 또한,  진동기둥(30)의 하측이 되는 막대(32)는 강연선(鋼撚線,  strand)으로 되거나 또는 탄소섬유(carbon
# [0032]
# fiber)나 유리섬유(glass  fiber)나 아라미드섬유(aramid  fiber)나 초고분자폴리에틸렌(UHMWPE)섬유 중의 어느
# 하나에 에폭시 등의 수지(樹脂, resin)제품을 함침(含浸, impregnation)시킨 섬유강화복합재료의 재질로 되는
# 것을 특징으로 하는 풍력진동발전기를 제공하고자 한다.
# 또한, 권선체(22)에 감겨진 코일(222)의 중심축이 고정부 원형 판(21)의 중앙부에 형성된 빈 공간인 구멍의 외
# [0033]
# 측가장자리둘레 근처의 소정위치에서부터 수평의 방향으로 원형 판(21)의 외측바깥쪽으로 향하게 되는 방사선모
# 양으로 다수가 구비되는 것을 특징으로 하는 풍력진동발전기를 제공하고자 한다.
# 또한, 권선체(22)에 감겨진 코일(222)의 중심축이 수직인 상태에서 권선체(22)의 일 측 끝단은 고정부 원형 판
# [0034]
# (21)의 위쪽으로 향하고 다른 일 측의 끝단은 고정부 원형 판(21)의 아래쪽으로 향하면서 그 중간은 고정부 원
# 형 판(21)  중앙부의 빈공간인 구멍의 외측가장자리둘레 근처의 소정위치에 있게 되는 상태로 고정부 원형 판
# (21) 중앙부의 빈공간인 구멍의 외측가장자리둘레 근처를 따라 일정한 간격으로 다수의 권선체(22)가 구비되는
# 것을 특징으로 하는 풍력진동발전기를 제공하고자 한다.
# 발명의 효과
# 본 발명에 의한 풍력진동발전기는 그 구성들이 아주 간단하면서도 특히나 무게가 아주 가벼워서 제작과 설치가
# [0035]
# 쉽고도 용이하여 이에 소요되는 비용은 실용적인 상업목적의 수평풍차방식에 의한 풍력발전기에는 비교를 할 수
# 조차도 없을 만큼 저렴해지게 될 뿐만 아니라 자연재해수준의 초강력태풍이 아닌 이상 아주 약한 바람이든 상당
# 히 강한 바람이든 어떠한 풍속의 영역 하에서도 항상 흔들리면서 전기를 생산할 수가 있는 되어 소요되는 비용
# 과 생산되는 전력과의 상호관계적인 효율이 아주 우수할 뿐만 아니라 날개가 없음으로 인하여 소음이 없게 되는
# 것은 물론이고 사람들에게 날개의 회전에 따라 위험해 보이는 불안감이나 날개가 파손되거나 부러져서 낙하하는
# 것들과 같은 위험성들을 모두 배제하여서는 사람들과는 아주 친숙하게 일반 가정주택의 앞마당이나 주택인근의
# 산이나 유휴지, 공원, 야산, 들판, 공용도로의 주변 등 어디든 누구나가 쉽게 설치를 하여 발전을 할 수가 있는
# 실용적이고도 진보적인 날개가 없는 풍력진동발전기로서 지금까지는 대부분의 사람들이 풍력발전이라는 분야에
# 는 쉽게 접근을 하지 못 하고 그저 대규모의 자금이 동원되어야만 하는 어렵고도 힘든 분야로만 인식이 되어 있
# 는 현실을 개선하여 실용적이면서도 아주 저렴한 현실적인 풍력발전이 사회전반에 걸쳐서 폭 넓게 보급될 수가
# 있도록 하는 상당히 큰 사회기여의 효과가 있게 된다.
#
# 요약:
# 본 발명은 풍력진동발전기에 관한 것으로서, 더 상세하게는 무게가 아주 가벼우면서도 바람에 아주 쉽게 잘 흔들
# 리는 진동기둥과 코일 및 영구자석으로 이루어지는 수평방향의 선형운동에 의한 진동발전기를 구비하여 바람에
# 의하여 흔들리는 풍력기둥의 수평진동에너지를 전기에너지로 전환을 시키도록 하는 날개가 없는 상태의 풍력진동
# Processing complete.

# %%
import fitz
import json
import requests
import os
import re

def download_pdf(url, filename):
    response = requests.get(url)
    with open(filename, 'wb') as f:
        f.write(response.content)

def extract_content(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()

    content = {
        '청구항': '',
        '요약': ''
    }

    # 요약 추출
    summary_match = re.search(r'\(\d+\)\s*요\s*약(.*?)(?=청구범위|$)', full_text, re.DOTALL)
    if summary_match:
        summary = summary_match.group(1).strip()
        summary = re.sub(r'\(뒷면에 계속\)\s*', '', summary)
        content['요약'] = summary

    # 청구항 추출
    claims_match = re.search(r'청구범위(.*?)(?:발명의 설명|발명의 내용|과제의 해결 수단|$)', full_text, re.DOTALL)
    if claims_match:
        claims = claims_match.group(1).strip()
        claims = re.split(r'(청구항\s*\d+)', claims)
        if len(claims) > 1:
            content['청구항1'] = (claims[1] + claims[2]).strip()
            content['청구항_나머지'] = ''.join(claims[3:]).strip()
        else:
            content['청구항'] = claims[0].strip()

    return content

# JSON 파일에서 특허 데이터 로드
input_file = '/home/user/hjkim/contextual/pdf_register_data(1-20,000).json'
with open(input_file, 'r') as f:
    patent_data = json.load(f)

# 처음 한 개의 PDF만 처리
for patent_number, pdf_url in list(patent_data.items())[:1]:
    pdf_filename = f"{patent_number}.pdf"
    print(f"\nProcessing patent number: {patent_number}")
    
    try:
        download_pdf(pdf_url, pdf_filename)
        content = extract_content(pdf_filename)
        
        print("\n청구항1:")
        print(content.get('청구항1', 'Not found'))
        
        print("\n청구항 나머지:")
        print(content.get('청구항_나머지', 'Not found'))
        
        print("\n요약:")
        print(content['요약'] if content['요약'] else 'Not found')
        
    except Exception as e:
        print(f"Error processing {patent_number}: {str(e)}")
    finally:
        if os.path.exists(pdf_filename):
            os.remove(pdf_filename)

print("Processing complete.")
# Out:
# Processing patent number: 1020170035102
#
# 청구항1:
# 청구항 1
# 소정의 형상과 재질로 되어서 일정길이를 가지며 하단부가 지면에 고정되는 한 개 이상의 고정기둥(10);과
# 중앙부에 소정크기의 구멍인 빈공간이 형성 된 고정부 원형 판(21)에서 빈 공간인 구멍의 외측 가장자리둘레 부
# 분을 따라 일정한 간격으로 보빈(bobbin)(221)에 코일(coil)(222)이 감겨진 다수의 권선체(22)들이 배열된 코일
# 고정판(20);과,
# 소정의 굵기와 재질과 형상으로 일정 길이를 가지며 내부가 비어 있거나 채워져 있는 풍력기둥(31)과, 풍력기둥
# (31)의 하단에는 고정기둥(10)의 상측에 그 하단이 고정되도록 하는 소정의 길이를 가지며 그 단면의
# 크기(굵기)가 상기 풍력기둥(31)의 단면크기(굵기) 보다가 일정크기만큼 더 작은 진동막대(32)가 달린 진동기둥
# (30);과
# 원형으로 된 진동부 원형 판(41)의 가장자리 근처의 둘레를 따라 원형의 영구자석(42)이 배치된 원형의 진동자
# 석판(40);으로 이루어져서,
# 원형의 코일고정판(20)은 그 외측둘레가 고정기둥(10)의 상부외측둘레에서 위쪽으로 돌출된 지지부재(23)에 지
# 지가 되어 고정이 되는 상태의 수평방향으로 배치가 되며 원형의 진동자석판(40)은 원형의 코일고정판(20)과 일
# 정거리 이격된 근접하는 위치에서 그 중심이 진동기둥(30)의 막대(32)에 결박되어 구속되는 상태의 수평방향으
# 로 배치가 되어 진동기둥(30)이 바람에 의하여 흔들리면서 진동을 함에 따라 진동자석판(40)은 그 중심이 진동
# 기둥(30) 아래쪽의 진동막대(32)에 결박되어 진동막대(32)와 함께 수평왕복의 진동운동을 하게 되어 고정기둥의
# 상측에서 진동자석판(40)과 가깝게 근접하여 고정된 코일고정판(20)의 권선체(22)에 감긴 코일(coil)(222)에는
# 영구자석(42)이 가깝게 근접하여 연속적으로 수평왕복의 진동운동을 하게 되고 그에 따라 코일(coil)(222)에서
# 는 연속적인 자기장의 변화와 함께 유도전기가 발생되도록 하는 것을 특징으로 하는 풍력진동발전기.
#
# 청구항 나머지:
# 청구항 2
# 청구항 1에 있어서,
# 원형의 진동자석판(40)과 원형의 코일고정판(20)은 각각 한 개 이상 여러 개를 구비하여 고정기둥(10)의 상측인
# 진동막대(32)부분에서 원형의 진동자석판(40)들과 원형의 코일고정판(20)들을 수직방향의 일정간격으로 하나씩
# 하나씩 교대로 번갈아가면서 서로 가깝게 인접하는 수평의 방향이 되도록 배치되는 것을 특징으로 하는 풍력진
# 동발전기.
# 청구항 3
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)은 위쪽으로 갈수록 단면이 점점 더 커지는 거꾸로 된 원추형의 모양
# 으로 구비가 되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 4
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)의 상단부에는 소정의 무게를 가지는 무게장치(33)가 별도로 구비된
# 것을 특징으로 하는 풍력진동발전기.
# 청구항 5
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)에는 그 표면에 소정의 형상으로 된 다수의 돌기(311)들이 형성된 것
# 을 특징으로 하는 풍력진동발전기.
# 등록특허 10-1910526
# - 3 -
# 청구항 6
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)은 탄소섬유(carbon fiber) 또는 유리섬유(glass fiber) 또는 아라미
# 드섬유(aramid fiber)나 초고분자폴리에틸렌(UHMWPE)섬유 중의 어느 하나에 에폭시 등의 수지(樹脂, resin)제품
# 을 함침(含浸, impregnation)시킨 섬유강화복합재료의 재질로 형성이 되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 7
# 청구항 1에 있어서,
# 진동기둥(30)의 하측이 되는 막대(32)는 강연선(鋼撚線, strand)으로 되거나 또는 탄소섬유(carbon fiber)나 유
# 리섬유(glass fiber)나 아라미드섬유(aramid fiber)나 초고분자폴리에틸렌(UHMWPE)섬유 중의 어느 하나에 에폭
# 시 등의 수지(樹脂, resin)제품을 함침(含浸, impregnation)시킨 섬유강화복합재료의 재질로 되는 것을 특징으
# 로 하는 풍력진동발전기.
# 청구항 8
# 청구항 1에 있어서,
# 권선체(22)에 감겨진 코일(coil)(222)의 중심축이 고정부 원형 판(21)의 중앙부에 형성된 빈 공간인 구멍의 외
# 측가장자리둘레 근처의 소정위치에서부터 수평의 방향으로 원형 판(21)의 외측바깥쪽으로 향하게 되는 방사선모
# 양으로 다수가 구비되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 9
# 청구항 1에 있어서,
# 권선체(22)에 감겨진 코일(coil)(222)의 중심축이 수직인 상태에서 권선체(22)의 일 측 끝단은 고정부 원형 판
# (21)의 위쪽으로 향하고 다른 일 측의 끝단은 고정부 원형 판(21)의 아래쪽으로 향하면서 그 중간은 고정부 원
# 형 판(21)  중앙부의 빈공간인 구멍의 외측가장자리둘레 근처의 소정위치에 있게 되는 상태로 고정부 원형 판
# (21) 중앙부의 빈공간인 구멍의 외측가장자리둘레 근처를 따라 일정한 간격으로 다수의 권선체(22)가 구비되는
# 것을 특징으로 하는 풍력진동발전기.
#
# 요약:
# 본 발명은 풍력진동발전기에 관한 것으로서, 더 상세하게는 무게가 아주 가벼우면서도 바람에 아주 쉽게 잘 흔들
# 리는 진동기둥과 코일 및 영구자석으로 이루어지는 수평방향의 선형운동에 의한 진동발전기를 구비하여 바람에
# 의하여 흔들리는 풍력기둥의 수평진동에너지를 전기에너지로 전환을 시키도록 하는 날개가 없는 상태의 풍력진동
# 대 표 도 - 도2
# 등록특허 10-1910526
# - 1 -
# 발전기를 아주 저렴한 비용으로서 제작을 하여 설치를 하도록 함과 동시에 날개가 없음으로 인한 높은 안전성으
# 로서 사람들과 친숙하게 일반 가정주택의 앞마당이나 주택인근의 산이나 유휴지, 공원, 야산, 들판, 공용도로의
# 주변 등 어디든 누구나가 쉽게 설치를 하여 발전을 할 수가 있도록 하는 현실적이고도 실용적인 회전날개가 없는
# 풍력진동발전기에 관한 것이다.
# 본 발명의 바람직한 일실시 예는 하단부가 지면에 고정되는 한 개 이상의 고정기둥;과 중심부에 소정크기의 구멍
# 인 빈공간이 형성 된 고정부 원형 판의 가장자리둘레를 따라 일정한 간격으로 다수의 권선체들이 배열된 코일고
# 정판;과, 길이가 긴 풍력기둥의 하단에는 고정기둥의 상측에서 고정되며 풍력기둥 보다가 그 굵기가 더 작은 진
# 동막대가 달린 진동기둥;과 원형으로 된 진동부 원형 판의 가장자리 둘레에는 원형의 영구자석이 배치된 원형의
# 진동자석판;으로 이루어져서, 원형의 코일고정판은 고정기둥의 상측에서 수평방향으로 고정이 되어 원형의 진동
# 자석판이 원형의 코일고정판과 아주 가깝게 인접하면서 진동기둥의 막대에 결박이 된 상태에서 진동기둥과 함께
# 바람에 의하여 수평으로 흔들림에 따른 영구자석의 진동왕복운동에 의하여 인접한 코일고정판의 권선체에 감긴
# 코일에서는 연속적인 자기장의 변화로 인한 유도전기가 발생되도록 한다.
# (52) CPC특허분류
#      F03D 5/06 (2013.01)
#      F03D 9/11 (2016.05)
#      H02K 35/02 (2013.01)
#      Y02E 10/725 (2013.01)
# 등록특허 10-1910526
# - 2 -
# 명 세 서
# Processing complete.

# %%
import fitz
import json
import requests
import os
import re

def download_pdf(url, filename):
    response = requests.get(url)
    with open(filename, 'wb') as f:
        f.write(response.content)

def extract_content(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()

    content = {
        '청구항': '',
        '요약': ''
    }

    # 요약 추출
    summary_match = re.search(r'\(\d+\)\s*요\s*약(.*?)(?=청구범위|$)', full_text, re.DOTALL)
    if summary_match:
        summary = summary_match.group(1).strip()
        # 페이지 넘김 표시 및 페이지 번호 제거
        summary = re.sub(r'\(뒷면에\s*계속\)\s*', '', summary)
        summary = re.sub(r'\d+\s*$', '', summary, flags=re.MULTILINE)
        # 여러 줄의 공백을 하나의 공백으로 대체
        summary = re.sub(r'\s+', ' ', summary)
        content['요약'] = summary

    # 청구항 추출 (기존 코드와 동일)
    claims_match = re.search(r'청구범위(.*?)(?:발명의 설명|발명의 내용|과제의 해결 수단|$)', full_text, re.DOTALL)
    if claims_match:
        claims = claims_match.group(1).strip()
        claims = re.split(r'(청구항\s*\d+)', claims)
        if len(claims) > 1:
            content['청구항1'] = (claims[1] + claims[2]).strip()
            content['청구항_나머지'] = ''.join(claims[3:]).strip()
        else:
            content['청구항'] = claims[0].strip()

    return content

# JSON 파일에서 특허 데이터 로드
input_file = '/home/user/hjkim/contextual/pdf_register_data(1-20,000).json'
with open(input_file, 'r') as f:
    patent_data = json.load(f)

# 처음 한 개의 PDF만 처리
for patent_number, pdf_url in list(patent_data.items())[:1]:
    pdf_filename = f"{patent_number}.pdf"
    print(f"\nProcessing patent number: {patent_number}")
    
    try:
        download_pdf(pdf_url, pdf_filename)
        content = extract_content(pdf_filename)
        
        print("\n청구항1:")
        print(content.get('청구항1', 'Not found'))
        
        print("\n청구항 나머지:")
        print(content.get('청구항_나머지', 'Not found'))
        
        print("\n요약:")
        print(content['요약'] if content['요약'] else 'Not found')
        
    except Exception as e:
        print(f"Error processing {patent_number}: {str(e)}")
    finally:
        if os.path.exists(pdf_filename):
            os.remove(pdf_filename)

print("Processing complete.")
# Out:
# Processing patent number: 1020170035102
#
# 청구항1:
# 청구항 1
# 소정의 형상과 재질로 되어서 일정길이를 가지며 하단부가 지면에 고정되는 한 개 이상의 고정기둥(10);과
# 중앙부에 소정크기의 구멍인 빈공간이 형성 된 고정부 원형 판(21)에서 빈 공간인 구멍의 외측 가장자리둘레 부
# 분을 따라 일정한 간격으로 보빈(bobbin)(221)에 코일(coil)(222)이 감겨진 다수의 권선체(22)들이 배열된 코일
# 고정판(20);과,
# 소정의 굵기와 재질과 형상으로 일정 길이를 가지며 내부가 비어 있거나 채워져 있는 풍력기둥(31)과, 풍력기둥
# (31)의 하단에는 고정기둥(10)의 상측에 그 하단이 고정되도록 하는 소정의 길이를 가지며 그 단면의
# 크기(굵기)가 상기 풍력기둥(31)의 단면크기(굵기) 보다가 일정크기만큼 더 작은 진동막대(32)가 달린 진동기둥
# (30);과
# 원형으로 된 진동부 원형 판(41)의 가장자리 근처의 둘레를 따라 원형의 영구자석(42)이 배치된 원형의 진동자
# 석판(40);으로 이루어져서,
# 원형의 코일고정판(20)은 그 외측둘레가 고정기둥(10)의 상부외측둘레에서 위쪽으로 돌출된 지지부재(23)에 지
# 지가 되어 고정이 되는 상태의 수평방향으로 배치가 되며 원형의 진동자석판(40)은 원형의 코일고정판(20)과 일
# 정거리 이격된 근접하는 위치에서 그 중심이 진동기둥(30)의 막대(32)에 결박되어 구속되는 상태의 수평방향으
# 로 배치가 되어 진동기둥(30)이 바람에 의하여 흔들리면서 진동을 함에 따라 진동자석판(40)은 그 중심이 진동
# 기둥(30) 아래쪽의 진동막대(32)에 결박되어 진동막대(32)와 함께 수평왕복의 진동운동을 하게 되어 고정기둥의
# 상측에서 진동자석판(40)과 가깝게 근접하여 고정된 코일고정판(20)의 권선체(22)에 감긴 코일(coil)(222)에는
# 영구자석(42)이 가깝게 근접하여 연속적으로 수평왕복의 진동운동을 하게 되고 그에 따라 코일(coil)(222)에서
# 는 연속적인 자기장의 변화와 함께 유도전기가 발생되도록 하는 것을 특징으로 하는 풍력진동발전기.
#
# 청구항 나머지:
# 청구항 2
# 청구항 1에 있어서,
# 원형의 진동자석판(40)과 원형의 코일고정판(20)은 각각 한 개 이상 여러 개를 구비하여 고정기둥(10)의 상측인
# 진동막대(32)부분에서 원형의 진동자석판(40)들과 원형의 코일고정판(20)들을 수직방향의 일정간격으로 하나씩
# 하나씩 교대로 번갈아가면서 서로 가깝게 인접하는 수평의 방향이 되도록 배치되는 것을 특징으로 하는 풍력진
# 동발전기.
# 청구항 3
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)은 위쪽으로 갈수록 단면이 점점 더 커지는 거꾸로 된 원추형의 모양
# 으로 구비가 되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 4
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)의 상단부에는 소정의 무게를 가지는 무게장치(33)가 별도로 구비된
# 것을 특징으로 하는 풍력진동발전기.
# 청구항 5
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)에는 그 표면에 소정의 형상으로 된 다수의 돌기(311)들이 형성된 것
# 을 특징으로 하는 풍력진동발전기.
# 등록특허 10-1910526
# - 3 -
# 청구항 6
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)은 탄소섬유(carbon fiber) 또는 유리섬유(glass fiber) 또는 아라미
# 드섬유(aramid fiber)나 초고분자폴리에틸렌(UHMWPE)섬유 중의 어느 하나에 에폭시 등의 수지(樹脂, resin)제품
# 을 함침(含浸, impregnation)시킨 섬유강화복합재료의 재질로 형성이 되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 7
# 청구항 1에 있어서,
# 진동기둥(30)의 하측이 되는 막대(32)는 강연선(鋼撚線, strand)으로 되거나 또는 탄소섬유(carbon fiber)나 유
# 리섬유(glass fiber)나 아라미드섬유(aramid fiber)나 초고분자폴리에틸렌(UHMWPE)섬유 중의 어느 하나에 에폭
# 시 등의 수지(樹脂, resin)제품을 함침(含浸, impregnation)시킨 섬유강화복합재료의 재질로 되는 것을 특징으
# 로 하는 풍력진동발전기.
# 청구항 8
# 청구항 1에 있어서,
# 권선체(22)에 감겨진 코일(coil)(222)의 중심축이 고정부 원형 판(21)의 중앙부에 형성된 빈 공간인 구멍의 외
# 측가장자리둘레 근처의 소정위치에서부터 수평의 방향으로 원형 판(21)의 외측바깥쪽으로 향하게 되는 방사선모
# 양으로 다수가 구비되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 9
# 청구항 1에 있어서,
# 권선체(22)에 감겨진 코일(coil)(222)의 중심축이 수직인 상태에서 권선체(22)의 일 측 끝단은 고정부 원형 판
# (21)의 위쪽으로 향하고 다른 일 측의 끝단은 고정부 원형 판(21)의 아래쪽으로 향하면서 그 중간은 고정부 원
# 형 판(21)  중앙부의 빈공간인 구멍의 외측가장자리둘레 근처의 소정위치에 있게 되는 상태로 고정부 원형 판
# (21) 중앙부의 빈공간인 구멍의 외측가장자리둘레 근처를 따라 일정한 간격으로 다수의 권선체(22)가 구비되는
# 것을 특징으로 하는 풍력진동발전기.
#
# 요약:
# 본 발명은 풍력진동발전기에 관한 것으로서, 더 상세하게는 무게가 아주 가벼우면서도 바람에 아주 쉽게 잘 흔들 리는 진동기둥과 코일 및 영구자석으로 이루어지는 수평방향의 선형운동에 의한 진동발전기를 구비하여 바람에 의하여 흔들리는 풍력기둥의 수평진동에너지를 전기에너지로 전환을 시키도록 하는 날개가 없는 상태의 풍력진동 대 표 도 - 도 등록특허 10- - 1 - 발전기를 아주 저렴한 비용으로서 제작을 하여 설치를 하도록 함과 동시에 날개가 없음으로 인한 높은 안전성으 로서 사람들과 친숙하게 일반 가정주택의 앞마당이나 주택인근의 산이나 유휴지, 공원, 야산, 들판, 공용도로의 주변 등 어디든 누구나가 쉽게 설치를 하여 발전을 할 수가 있도록 하는 현실적이고도 실용적인 회전날개가 없는 풍력진동발전기에 관한 것이다. 본 발명의 바람직한 일실시 예는 하단부가 지면에 고정되는 한 개 이상의 고정기둥;과 중심부에 소정크기의 구멍 인 빈공간이 형성 된 고정부 원형 판의 가장자리둘레를 따라 일정한 간격으로 다수의 권선체들이 배열된 코일고 정판;과, 길이가 긴 풍력기둥의 하단에는 고정기둥의 상측에서 고정되며 풍력기둥 보다가 그 굵기가 더 작은 진 동막대가 달린 진동기둥;과 원형으로 된 진동부 원형 판의 가장자리 둘레에는 원형의 영구자석이 배치된 원형의 진동자석판;으로 이루어져서, 원형의 코일고정판은 고정기둥의 상측에서 수평방향으로 고정이 되어 원형의 진동 자석판이 원형의 코일고정판과 아주 가깝게 인접하면서 진동기둥의 막대에 결박이 된 상태에서 진동기둥과 함께 바람에 의하여 수평으로 흔들림에 따른 영구자석의 진동왕복운동에 의하여 인접한 코일고정판의 권선체에 감긴 코일에서는 연속적인 자기장의 변화로 인한 유도전기가 발생되도록 한다. (52) CPC특허분류 F03D 5/06 (2013.01) F03D 9/11 (2016.05) H02K 35/02 (2013.01) Y02E 10/725 (2013.01) 등록특허 10- - 2 - 명 세 서
# Processing complete.

# %%
import fitz
import json
import requests
import os
import re

def download_pdf(url, filename):
    response = requests.get(url)
    with open(filename, 'wb') as f:
        f.write(response.content)


def extract_content(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()

    content = {
        '청구항': '',
        '요약': ''
    }

    # 요약 추출
    summary_match = re.search(r'\(\d+\)\s*요\s*약(.*?)(?=청구범위|$)', full_text, re.DOTALL)
    if summary_match:
        summary = summary_match.group(1).strip()
        # 페이지 넘김 표시 및 페이지 번호 제거
        summary = re.sub(r'\(뒷면에\s*계속\)\s*', '', summary)
        summary = re.sub(r'\d+\s*$', '', summary, flags=re.MULTILINE)
        # 기울어진 텍스트 제거 (일반적으로 이탤릭체로 표시됨)
        summary = re.sub(r'<i>.*?</i>', '', summary)
        # 등록특허 뒤의 숫자들 제거
        summary = re.sub(r'등록특허\s*\d+(-\d+)*', '등록특허', summary)
        # 여러 줄의 공백을 하나의 공백으로 대체
        summary = re.sub(r'\s+', ' ', summary)
        content['요약'] = summary.strip()

    # 청구항 추출 (기존 코드와 동일)
    claims_match = re.search(r'청구범위(.*?)(?:발명의 설명|발명의 내용|과제의 해결 수단|$)', full_text, re.DOTALL)
    if claims_match:
        claims = claims_match.group(1).strip()
        claims = re.split(r'(청구항\s*\d+)', claims)
        if len(claims) > 1:
            content['청구항1'] = (claims[1] + claims[2]).strip()
            content['청구항_나머지'] = ''.join(claims[3:]).strip()
        else:
            content['청구항'] = claims[0].strip()

    return content

# JSON 파일에서 특허 데이터 로드
input_file = '/home/user/hjkim/contextual/pdf_register_data(1-20,000).json'
with open(input_file, 'r') as f:
    patent_data = json.load(f)

# 처음 한 개의 PDF만 처리
for patent_number, pdf_url in list(patent_data.items())[:1]:
    pdf_filename = f"{patent_number}.pdf"
    print(f"\nProcessing patent number: {patent_number}")
    
    try:
        download_pdf(pdf_url, pdf_filename)
        content = extract_content(pdf_filename)
        
        print("\n청구항1:")
        print(content.get('청구항1', 'Not found'))
        
        print("\n청구항 나머지:")
        print(content.get('청구항_나머지', 'Not found'))
        
        print("\n요약:")
        print(content['요약'] if content['요약'] else 'Not found')
        
    except Exception as e:
        print(f"Error processing {patent_number}: {str(e)}")
    finally:
        if os.path.exists(pdf_filename):
            os.remove(pdf_filename)

print("Processing complete.")
# Out:
# Processing patent number: 1020170035102
#
# 청구항1:
# 청구항 1
# 소정의 형상과 재질로 되어서 일정길이를 가지며 하단부가 지면에 고정되는 한 개 이상의 고정기둥(10);과
# 중앙부에 소정크기의 구멍인 빈공간이 형성 된 고정부 원형 판(21)에서 빈 공간인 구멍의 외측 가장자리둘레 부
# 분을 따라 일정한 간격으로 보빈(bobbin)(221)에 코일(coil)(222)이 감겨진 다수의 권선체(22)들이 배열된 코일
# 고정판(20);과,
# 소정의 굵기와 재질과 형상으로 일정 길이를 가지며 내부가 비어 있거나 채워져 있는 풍력기둥(31)과, 풍력기둥
# (31)의 하단에는 고정기둥(10)의 상측에 그 하단이 고정되도록 하는 소정의 길이를 가지며 그 단면의
# 크기(굵기)가 상기 풍력기둥(31)의 단면크기(굵기) 보다가 일정크기만큼 더 작은 진동막대(32)가 달린 진동기둥
# (30);과
# 원형으로 된 진동부 원형 판(41)의 가장자리 근처의 둘레를 따라 원형의 영구자석(42)이 배치된 원형의 진동자
# 석판(40);으로 이루어져서,
# 원형의 코일고정판(20)은 그 외측둘레가 고정기둥(10)의 상부외측둘레에서 위쪽으로 돌출된 지지부재(23)에 지
# 지가 되어 고정이 되는 상태의 수평방향으로 배치가 되며 원형의 진동자석판(40)은 원형의 코일고정판(20)과 일
# 정거리 이격된 근접하는 위치에서 그 중심이 진동기둥(30)의 막대(32)에 결박되어 구속되는 상태의 수평방향으
# 로 배치가 되어 진동기둥(30)이 바람에 의하여 흔들리면서 진동을 함에 따라 진동자석판(40)은 그 중심이 진동
# 기둥(30) 아래쪽의 진동막대(32)에 결박되어 진동막대(32)와 함께 수평왕복의 진동운동을 하게 되어 고정기둥의
# 상측에서 진동자석판(40)과 가깝게 근접하여 고정된 코일고정판(20)의 권선체(22)에 감긴 코일(coil)(222)에는
# 영구자석(42)이 가깝게 근접하여 연속적으로 수평왕복의 진동운동을 하게 되고 그에 따라 코일(coil)(222)에서
# 는 연속적인 자기장의 변화와 함께 유도전기가 발생되도록 하는 것을 특징으로 하는 풍력진동발전기.
#
# 청구항 나머지:
# 청구항 2
# 청구항 1에 있어서,
# 원형의 진동자석판(40)과 원형의 코일고정판(20)은 각각 한 개 이상 여러 개를 구비하여 고정기둥(10)의 상측인
# 진동막대(32)부분에서 원형의 진동자석판(40)들과 원형의 코일고정판(20)들을 수직방향의 일정간격으로 하나씩
# 하나씩 교대로 번갈아가면서 서로 가깝게 인접하는 수평의 방향이 되도록 배치되는 것을 특징으로 하는 풍력진
# 동발전기.
# 청구항 3
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)은 위쪽으로 갈수록 단면이 점점 더 커지는 거꾸로 된 원추형의 모양
# 으로 구비가 되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 4
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)의 상단부에는 소정의 무게를 가지는 무게장치(33)가 별도로 구비된
# 것을 특징으로 하는 풍력진동발전기.
# 청구항 5
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)에는 그 표면에 소정의 형상으로 된 다수의 돌기(311)들이 형성된 것
# 을 특징으로 하는 풍력진동발전기.
# 등록특허 10-1910526
# - 3 -
# 청구항 6
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)은 탄소섬유(carbon fiber) 또는 유리섬유(glass fiber) 또는 아라미
# 드섬유(aramid fiber)나 초고분자폴리에틸렌(UHMWPE)섬유 중의 어느 하나에 에폭시 등의 수지(樹脂, resin)제품
# 을 함침(含浸, impregnation)시킨 섬유강화복합재료의 재질로 형성이 되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 7
# 청구항 1에 있어서,
# 진동기둥(30)의 하측이 되는 막대(32)는 강연선(鋼撚線, strand)으로 되거나 또는 탄소섬유(carbon fiber)나 유
# 리섬유(glass fiber)나 아라미드섬유(aramid fiber)나 초고분자폴리에틸렌(UHMWPE)섬유 중의 어느 하나에 에폭
# 시 등의 수지(樹脂, resin)제품을 함침(含浸, impregnation)시킨 섬유강화복합재료의 재질로 되는 것을 특징으
# 로 하는 풍력진동발전기.
# 청구항 8
# 청구항 1에 있어서,
# 권선체(22)에 감겨진 코일(coil)(222)의 중심축이 고정부 원형 판(21)의 중앙부에 형성된 빈 공간인 구멍의 외
# 측가장자리둘레 근처의 소정위치에서부터 수평의 방향으로 원형 판(21)의 외측바깥쪽으로 향하게 되는 방사선모
# 양으로 다수가 구비되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 9
# 청구항 1에 있어서,
# 권선체(22)에 감겨진 코일(coil)(222)의 중심축이 수직인 상태에서 권선체(22)의 일 측 끝단은 고정부 원형 판
# (21)의 위쪽으로 향하고 다른 일 측의 끝단은 고정부 원형 판(21)의 아래쪽으로 향하면서 그 중간은 고정부 원
# 형 판(21)  중앙부의 빈공간인 구멍의 외측가장자리둘레 근처의 소정위치에 있게 되는 상태로 고정부 원형 판
# (21) 중앙부의 빈공간인 구멍의 외측가장자리둘레 근처를 따라 일정한 간격으로 다수의 권선체(22)가 구비되는
# 것을 특징으로 하는 풍력진동발전기.
#
# 요약:
# 본 발명은 풍력진동발전기에 관한 것으로서, 더 상세하게는 무게가 아주 가벼우면서도 바람에 아주 쉽게 잘 흔들 리는 진동기둥과 코일 및 영구자석으로 이루어지는 수평방향의 선형운동에 의한 진동발전기를 구비하여 바람에 의하여 흔들리는 풍력기둥의 수평진동에너지를 전기에너지로 전환을 시키도록 하는 날개가 없는 상태의 풍력진동 대 표 도 - 도 등록특허- - 1 - 발전기를 아주 저렴한 비용으로서 제작을 하여 설치를 하도록 함과 동시에 날개가 없음으로 인한 높은 안전성으 로서 사람들과 친숙하게 일반 가정주택의 앞마당이나 주택인근의 산이나 유휴지, 공원, 야산, 들판, 공용도로의 주변 등 어디든 누구나가 쉽게 설치를 하여 발전을 할 수가 있도록 하는 현실적이고도 실용적인 회전날개가 없는 풍력진동발전기에 관한 것이다. 본 발명의 바람직한 일실시 예는 하단부가 지면에 고정되는 한 개 이상의 고정기둥;과 중심부에 소정크기의 구멍 인 빈공간이 형성 된 고정부 원형 판의 가장자리둘레를 따라 일정한 간격으로 다수의 권선체들이 배열된 코일고 정판;과, 길이가 긴 풍력기둥의 하단에는 고정기둥의 상측에서 고정되며 풍력기둥 보다가 그 굵기가 더 작은 진 동막대가 달린 진동기둥;과 원형으로 된 진동부 원형 판의 가장자리 둘레에는 원형의 영구자석이 배치된 원형의 진동자석판;으로 이루어져서, 원형의 코일고정판은 고정기둥의 상측에서 수평방향으로 고정이 되어 원형의 진동 자석판이 원형의 코일고정판과 아주 가깝게 인접하면서 진동기둥의 막대에 결박이 된 상태에서 진동기둥과 함께 바람에 의하여 수평으로 흔들림에 따른 영구자석의 진동왕복운동에 의하여 인접한 코일고정판의 권선체에 감긴 코일에서는 연속적인 자기장의 변화로 인한 유도전기가 발생되도록 한다. (52) CPC특허분류 F03D 5/06 (2013.01) F03D 9/11 (2016.05) H02K 35/02 (2013.01) Y02E 10/725 (2013.01) 등록특허- - 2 - 명 세 서
# Processing complete.

# %%
import fitz
import json
import requests
import os
import re

def download_pdf(url, filename):
    response = requests.get(url)
    with open(filename, 'wb') as f:
        f.write(response.content)

def extract_content(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()

    content = {
        '청구항': '',
        '요약': ''
    }

    # 요약 추출
    summary_match = re.search(r'\(\d+\)\s*요\s*약(.*?)(?=청구범위|$)', full_text, re.DOTALL)
    if summary_match:
        summary = summary_match.group(1).strip()
        # 페이지 넘김 표시 및 페이지 번호 제거
        summary = re.sub(r'\(뒷면에\s*계속\)\s*', '', summary)
        summary = re.sub(r'\d+\s*$', '', summary, flags=re.MULTILINE)
        # 기울어진 텍스트 제거 (일반적으로 이탤릭체로 표시됨)
        summary = re.sub(r'<i>.*?</i>', '', summary)
        # 등록특허 뒤의 숫자들 제거
        summary = re.sub(r'등록특허\s*\d+(-\d+)*', '등록특허', summary)
        # "대 표 도 - 도" 및 "등록특허- - 1 -" 제거
        summary = re.sub(r'대\s*표\s*도\s*-\s*도', '', summary)
        summary = re.sub(r'등록특허-\s*-\s*\d+\s*-', '', summary)
        # 여러 줄의 공백을 하나의 공백으로 대체
        summary = re.sub(r'\s+', ' ', summary)
        content['요약'] = summary.strip()

    # 청구항 추출 (기존 코드와 동일)
    claims_match = re.search(r'청구범위(.*?)(?:발명의 설명|발명의 내용|과제의 해결 수단|$)', full_text, re.DOTALL)
    if claims_match:
        claims = claims_match.group(1).strip()
        claims = re.split(r'(청구항\s*\d+)', claims)
        if len(claims) > 1:
            content['청구항1'] = (claims[1] + claims[2]).strip()
            content['청구항_나머지'] = ''.join(claims[3:]).strip()
        else:
            content['청구항'] = claims[0].strip()

    return content

# JSON 파일에서 특허 데이터 로드
input_file = '/home/user/hjkim/contextual/pdf_register_data(1-20,000).json'
with open(input_file, 'r') as f:
    patent_data = json.load(f)

# 처음 한 개의 PDF만 처리
for patent_number, pdf_url in list(patent_data.items())[:1]:
    pdf_filename = f"{patent_number}.pdf"
    print(f"\nProcessing patent number: {patent_number}")
    
    try:
        download_pdf(pdf_url, pdf_filename)
        content = extract_content(pdf_filename)
        
        print("\n청구항1:")
        print(content.get('청구항1', 'Not found'))
        
        print("\n청구항 나머지:")
        print(content.get('청구항_나머지', 'Not found'))
        
        print("\n요약:")
        print(content['요약'] if content['요약'] else 'Not found')
        
    except Exception as e:
        print(f"Error processing {patent_number}: {str(e)}")
    finally:
        if os.path.exists(pdf_filename):
            os.remove(pdf_filename)

print("Processing complete.")
# Out:
# Processing patent number: 1020170035102
#
# 청구항1:
# 청구항 1
# 소정의 형상과 재질로 되어서 일정길이를 가지며 하단부가 지면에 고정되는 한 개 이상의 고정기둥(10);과
# 중앙부에 소정크기의 구멍인 빈공간이 형성 된 고정부 원형 판(21)에서 빈 공간인 구멍의 외측 가장자리둘레 부
# 분을 따라 일정한 간격으로 보빈(bobbin)(221)에 코일(coil)(222)이 감겨진 다수의 권선체(22)들이 배열된 코일
# 고정판(20);과,
# 소정의 굵기와 재질과 형상으로 일정 길이를 가지며 내부가 비어 있거나 채워져 있는 풍력기둥(31)과, 풍력기둥
# (31)의 하단에는 고정기둥(10)의 상측에 그 하단이 고정되도록 하는 소정의 길이를 가지며 그 단면의
# 크기(굵기)가 상기 풍력기둥(31)의 단면크기(굵기) 보다가 일정크기만큼 더 작은 진동막대(32)가 달린 진동기둥
# (30);과
# 원형으로 된 진동부 원형 판(41)의 가장자리 근처의 둘레를 따라 원형의 영구자석(42)이 배치된 원형의 진동자
# 석판(40);으로 이루어져서,
# 원형의 코일고정판(20)은 그 외측둘레가 고정기둥(10)의 상부외측둘레에서 위쪽으로 돌출된 지지부재(23)에 지
# 지가 되어 고정이 되는 상태의 수평방향으로 배치가 되며 원형의 진동자석판(40)은 원형의 코일고정판(20)과 일
# 정거리 이격된 근접하는 위치에서 그 중심이 진동기둥(30)의 막대(32)에 결박되어 구속되는 상태의 수평방향으
# 로 배치가 되어 진동기둥(30)이 바람에 의하여 흔들리면서 진동을 함에 따라 진동자석판(40)은 그 중심이 진동
# 기둥(30) 아래쪽의 진동막대(32)에 결박되어 진동막대(32)와 함께 수평왕복의 진동운동을 하게 되어 고정기둥의
# 상측에서 진동자석판(40)과 가깝게 근접하여 고정된 코일고정판(20)의 권선체(22)에 감긴 코일(coil)(222)에는
# 영구자석(42)이 가깝게 근접하여 연속적으로 수평왕복의 진동운동을 하게 되고 그에 따라 코일(coil)(222)에서
# 는 연속적인 자기장의 변화와 함께 유도전기가 발생되도록 하는 것을 특징으로 하는 풍력진동발전기.
#
# 청구항 나머지:
# 청구항 2
# 청구항 1에 있어서,
# 원형의 진동자석판(40)과 원형의 코일고정판(20)은 각각 한 개 이상 여러 개를 구비하여 고정기둥(10)의 상측인
# 진동막대(32)부분에서 원형의 진동자석판(40)들과 원형의 코일고정판(20)들을 수직방향의 일정간격으로 하나씩
# 하나씩 교대로 번갈아가면서 서로 가깝게 인접하는 수평의 방향이 되도록 배치되는 것을 특징으로 하는 풍력진
# 동발전기.
# 청구항 3
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)은 위쪽으로 갈수록 단면이 점점 더 커지는 거꾸로 된 원추형의 모양
# 으로 구비가 되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 4
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)의 상단부에는 소정의 무게를 가지는 무게장치(33)가 별도로 구비된
# 것을 특징으로 하는 풍력진동발전기.
# 청구항 5
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)에는 그 표면에 소정의 형상으로 된 다수의 돌기(311)들이 형성된 것
# 을 특징으로 하는 풍력진동발전기.
# 등록특허 10-1910526
# - 3 -
# 청구항 6
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)은 탄소섬유(carbon fiber) 또는 유리섬유(glass fiber) 또는 아라미
# 드섬유(aramid fiber)나 초고분자폴리에틸렌(UHMWPE)섬유 중의 어느 하나에 에폭시 등의 수지(樹脂, resin)제품
# 을 함침(含浸, impregnation)시킨 섬유강화복합재료의 재질로 형성이 되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 7
# 청구항 1에 있어서,
# 진동기둥(30)의 하측이 되는 막대(32)는 강연선(鋼撚線, strand)으로 되거나 또는 탄소섬유(carbon fiber)나 유
# 리섬유(glass fiber)나 아라미드섬유(aramid fiber)나 초고분자폴리에틸렌(UHMWPE)섬유 중의 어느 하나에 에폭
# 시 등의 수지(樹脂, resin)제품을 함침(含浸, impregnation)시킨 섬유강화복합재료의 재질로 되는 것을 특징으
# 로 하는 풍력진동발전기.
# 청구항 8
# 청구항 1에 있어서,
# 권선체(22)에 감겨진 코일(coil)(222)의 중심축이 고정부 원형 판(21)의 중앙부에 형성된 빈 공간인 구멍의 외
# 측가장자리둘레 근처의 소정위치에서부터 수평의 방향으로 원형 판(21)의 외측바깥쪽으로 향하게 되는 방사선모
# 양으로 다수가 구비되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 9
# 청구항 1에 있어서,
# 권선체(22)에 감겨진 코일(coil)(222)의 중심축이 수직인 상태에서 권선체(22)의 일 측 끝단은 고정부 원형 판
# (21)의 위쪽으로 향하고 다른 일 측의 끝단은 고정부 원형 판(21)의 아래쪽으로 향하면서 그 중간은 고정부 원
# 형 판(21)  중앙부의 빈공간인 구멍의 외측가장자리둘레 근처의 소정위치에 있게 되는 상태로 고정부 원형 판
# (21) 중앙부의 빈공간인 구멍의 외측가장자리둘레 근처를 따라 일정한 간격으로 다수의 권선체(22)가 구비되는
# 것을 특징으로 하는 풍력진동발전기.
#
# 요약:
# 본 발명은 풍력진동발전기에 관한 것으로서, 더 상세하게는 무게가 아주 가벼우면서도 바람에 아주 쉽게 잘 흔들 리는 진동기둥과 코일 및 영구자석으로 이루어지는 수평방향의 선형운동에 의한 진동발전기를 구비하여 바람에 의하여 흔들리는 풍력기둥의 수평진동에너지를 전기에너지로 전환을 시키도록 하는 날개가 없는 상태의 풍력진동 발전기를 아주 저렴한 비용으로서 제작을 하여 설치를 하도록 함과 동시에 날개가 없음으로 인한 높은 안전성으 로서 사람들과 친숙하게 일반 가정주택의 앞마당이나 주택인근의 산이나 유휴지, 공원, 야산, 들판, 공용도로의 주변 등 어디든 누구나가 쉽게 설치를 하여 발전을 할 수가 있도록 하는 현실적이고도 실용적인 회전날개가 없는 풍력진동발전기에 관한 것이다. 본 발명의 바람직한 일실시 예는 하단부가 지면에 고정되는 한 개 이상의 고정기둥;과 중심부에 소정크기의 구멍 인 빈공간이 형성 된 고정부 원형 판의 가장자리둘레를 따라 일정한 간격으로 다수의 권선체들이 배열된 코일고 정판;과, 길이가 긴 풍력기둥의 하단에는 고정기둥의 상측에서 고정되며 풍력기둥 보다가 그 굵기가 더 작은 진 동막대가 달린 진동기둥;과 원형으로 된 진동부 원형 판의 가장자리 둘레에는 원형의 영구자석이 배치된 원형의 진동자석판;으로 이루어져서, 원형의 코일고정판은 고정기둥의 상측에서 수평방향으로 고정이 되어 원형의 진동 자석판이 원형의 코일고정판과 아주 가깝게 인접하면서 진동기둥의 막대에 결박이 된 상태에서 진동기둥과 함께 바람에 의하여 수평으로 흔들림에 따른 영구자석의 진동왕복운동에 의하여 인접한 코일고정판의 권선체에 감긴 코일에서는 연속적인 자기장의 변화로 인한 유도전기가 발생되도록 한다. (52) CPC특허분류 F03D 5/06 (2013.01) F03D 9/11 (2016.05) H02K 35/02 (2013.01) Y02E 10/725 (2013.01) 명 세 서
# Processing complete.

# %%
import fitz
import json
import requests
import os
import re

def download_pdf(url, filename):
    response = requests.get(url)
    with open(filename, 'wb') as f:
        f.write(response.content)

def extract_content(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()

    content = {
        '청구항': '',
        '요약': ''
    }

    # 요약 추출
    summary_match = re.search(r'\(\d+\)\s*요\s*약(.*?)(?=청구범위|$)', full_text, re.DOTALL)
    if summary_match:
        summary = summary_match.group(1).strip()
        # 페이지 넘김 표시 및 페이지 번호 제거
        summary = re.sub(r'\(뒷면에\s*계속\)\s*', '', summary)
        summary = re.sub(r'\d+\s*$', '', summary, flags=re.MULTILINE)
        # 기울어진 텍스트 제거 (일반적으로 이탤릭체로 표시됨)
        summary = re.sub(r'<i>.*?</i>', '', summary)
        # 등록특허 뒤의 숫자들 제거
        summary = re.sub(r'등록특허\s*\d+(-\d+)*', '등록특허', summary)
        # "대 표 도 - 도" 및 "등록특허- - 1 -" 제거
        summary = re.sub(r'대\s*표\s*도\s*-\s*도', '', summary)
        summary = re.sub(r'등록특허-\s*-\s*\d+\s*-', '', summary)
        # 괄호 안의 숫자와 그 이후의 텍스트 제거
        summary = re.sub(r'\(\d+\).*$', '', summary, flags=re.DOTALL)
        # 여러 줄의 공백을 하나의 공백으로 대체
        summary = re.sub(r'\s+', ' ', summary)
        content['요약'] = summary.strip()

    # 청구항 추출 (기존 코드와 동일)
    claims_match = re.search(r'청구범위(.*?)(?:발명의 설명|발명의 내용|과제의 해결 수단|$)', full_text, re.DOTALL)
    if claims_match:
        claims = claims_match.group(1).strip()
        claims = re.split(r'(청구항\s*\d+)', claims)
        if len(claims) > 1:
            content['청구항1'] = (claims[1] + claims[2]).strip()
            content['청구항_나머지'] = ''.join(claims[3:]).strip()
        else:
            content['청구항'] = claims[0].strip()

    return content

# JSON 파일에서 특허 데이터 로드
input_file = '/home/user/hjkim/contextual/pdf_register_data(1-20,000).json'
with open(input_file, 'r') as f:
    patent_data = json.load(f)

# 처음 한 개의 PDF만 처리
for patent_number, pdf_url in list(patent_data.items())[:1]:
    pdf_filename = f"{patent_number}.pdf"
    print(f"\nProcessing patent number: {patent_number}")
    
    try:
        download_pdf(pdf_url, pdf_filename)
        content = extract_content(pdf_filename)
        
        print("\n청구항1:")
        print(content.get('청구항1', 'Not found'))
        
        print("\n청구항 나머지:")
        print(content.get('청구항_나머지', 'Not found'))
        
        print("\n요약:")
        print(content['요약'] if content['요약'] else 'Not found')
        
    except Exception as e:
        print(f"Error processing {patent_number}: {str(e)}")
    finally:
        if os.path.exists(pdf_filename):
            os.remove(pdf_filename)

print("Processing complete.")
# Out:
# Processing patent number: 1020170035102
#
# 청구항1:
# 청구항 1
# 소정의 형상과 재질로 되어서 일정길이를 가지며 하단부가 지면에 고정되는 한 개 이상의 고정기둥(10);과
# 중앙부에 소정크기의 구멍인 빈공간이 형성 된 고정부 원형 판(21)에서 빈 공간인 구멍의 외측 가장자리둘레 부
# 분을 따라 일정한 간격으로 보빈(bobbin)(221)에 코일(coil)(222)이 감겨진 다수의 권선체(22)들이 배열된 코일
# 고정판(20);과,
# 소정의 굵기와 재질과 형상으로 일정 길이를 가지며 내부가 비어 있거나 채워져 있는 풍력기둥(31)과, 풍력기둥
# (31)의 하단에는 고정기둥(10)의 상측에 그 하단이 고정되도록 하는 소정의 길이를 가지며 그 단면의
# 크기(굵기)가 상기 풍력기둥(31)의 단면크기(굵기) 보다가 일정크기만큼 더 작은 진동막대(32)가 달린 진동기둥
# (30);과
# 원형으로 된 진동부 원형 판(41)의 가장자리 근처의 둘레를 따라 원형의 영구자석(42)이 배치된 원형의 진동자
# 석판(40);으로 이루어져서,
# 원형의 코일고정판(20)은 그 외측둘레가 고정기둥(10)의 상부외측둘레에서 위쪽으로 돌출된 지지부재(23)에 지
# 지가 되어 고정이 되는 상태의 수평방향으로 배치가 되며 원형의 진동자석판(40)은 원형의 코일고정판(20)과 일
# 정거리 이격된 근접하는 위치에서 그 중심이 진동기둥(30)의 막대(32)에 결박되어 구속되는 상태의 수평방향으
# 로 배치가 되어 진동기둥(30)이 바람에 의하여 흔들리면서 진동을 함에 따라 진동자석판(40)은 그 중심이 진동
# 기둥(30) 아래쪽의 진동막대(32)에 결박되어 진동막대(32)와 함께 수평왕복의 진동운동을 하게 되어 고정기둥의
# 상측에서 진동자석판(40)과 가깝게 근접하여 고정된 코일고정판(20)의 권선체(22)에 감긴 코일(coil)(222)에는
# 영구자석(42)이 가깝게 근접하여 연속적으로 수평왕복의 진동운동을 하게 되고 그에 따라 코일(coil)(222)에서
# 는 연속적인 자기장의 변화와 함께 유도전기가 발생되도록 하는 것을 특징으로 하는 풍력진동발전기.
#
# 청구항 나머지:
# 청구항 2
# 청구항 1에 있어서,
# 원형의 진동자석판(40)과 원형의 코일고정판(20)은 각각 한 개 이상 여러 개를 구비하여 고정기둥(10)의 상측인
# 진동막대(32)부분에서 원형의 진동자석판(40)들과 원형의 코일고정판(20)들을 수직방향의 일정간격으로 하나씩
# 하나씩 교대로 번갈아가면서 서로 가깝게 인접하는 수평의 방향이 되도록 배치되는 것을 특징으로 하는 풍력진
# 동발전기.
# 청구항 3
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)은 위쪽으로 갈수록 단면이 점점 더 커지는 거꾸로 된 원추형의 모양
# 으로 구비가 되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 4
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)의 상단부에는 소정의 무게를 가지는 무게장치(33)가 별도로 구비된
# 것을 특징으로 하는 풍력진동발전기.
# 청구항 5
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)에는 그 표면에 소정의 형상으로 된 다수의 돌기(311)들이 형성된 것
# 을 특징으로 하는 풍력진동발전기.
# 등록특허 10-1910526
# - 3 -
# 청구항 6
# 청구항 1에 있어서,
# 진동기둥(30)의 상측이 되는 풍력기둥(31)은 탄소섬유(carbon fiber) 또는 유리섬유(glass fiber) 또는 아라미
# 드섬유(aramid fiber)나 초고분자폴리에틸렌(UHMWPE)섬유 중의 어느 하나에 에폭시 등의 수지(樹脂, resin)제품
# 을 함침(含浸, impregnation)시킨 섬유강화복합재료의 재질로 형성이 되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 7
# 청구항 1에 있어서,
# 진동기둥(30)의 하측이 되는 막대(32)는 강연선(鋼撚線, strand)으로 되거나 또는 탄소섬유(carbon fiber)나 유
# 리섬유(glass fiber)나 아라미드섬유(aramid fiber)나 초고분자폴리에틸렌(UHMWPE)섬유 중의 어느 하나에 에폭
# 시 등의 수지(樹脂, resin)제품을 함침(含浸, impregnation)시킨 섬유강화복합재료의 재질로 되는 것을 특징으
# 로 하는 풍력진동발전기.
# 청구항 8
# 청구항 1에 있어서,
# 권선체(22)에 감겨진 코일(coil)(222)의 중심축이 고정부 원형 판(21)의 중앙부에 형성된 빈 공간인 구멍의 외
# 측가장자리둘레 근처의 소정위치에서부터 수평의 방향으로 원형 판(21)의 외측바깥쪽으로 향하게 되는 방사선모
# 양으로 다수가 구비되는 것을 특징으로 하는 풍력진동발전기.
# 청구항 9
# 청구항 1에 있어서,
# 권선체(22)에 감겨진 코일(coil)(222)의 중심축이 수직인 상태에서 권선체(22)의 일 측 끝단은 고정부 원형 판
# (21)의 위쪽으로 향하고 다른 일 측의 끝단은 고정부 원형 판(21)의 아래쪽으로 향하면서 그 중간은 고정부 원
# 형 판(21)  중앙부의 빈공간인 구멍의 외측가장자리둘레 근처의 소정위치에 있게 되는 상태로 고정부 원형 판
# (21) 중앙부의 빈공간인 구멍의 외측가장자리둘레 근처를 따라 일정한 간격으로 다수의 권선체(22)가 구비되는
# 것을 특징으로 하는 풍력진동발전기.
#
# 요약:
# 본 발명은 풍력진동발전기에 관한 것으로서, 더 상세하게는 무게가 아주 가벼우면서도 바람에 아주 쉽게 잘 흔들 리는 진동기둥과 코일 및 영구자석으로 이루어지는 수평방향의 선형운동에 의한 진동발전기를 구비하여 바람에 의하여 흔들리는 풍력기둥의 수평진동에너지를 전기에너지로 전환을 시키도록 하는 날개가 없는 상태의 풍력진동 발전기를 아주 저렴한 비용으로서 제작을 하여 설치를 하도록 함과 동시에 날개가 없음으로 인한 높은 안전성으 로서 사람들과 친숙하게 일반 가정주택의 앞마당이나 주택인근의 산이나 유휴지, 공원, 야산, 들판, 공용도로의 주변 등 어디든 누구나가 쉽게 설치를 하여 발전을 할 수가 있도록 하는 현실적이고도 실용적인 회전날개가 없는 풍력진동발전기에 관한 것이다. 본 발명의 바람직한 일실시 예는 하단부가 지면에 고정되는 한 개 이상의 고정기둥;과 중심부에 소정크기의 구멍 인 빈공간이 형성 된 고정부 원형 판의 가장자리둘레를 따라 일정한 간격으로 다수의 권선체들이 배열된 코일고 정판;과, 길이가 긴 풍력기둥의 하단에는 고정기둥의 상측에서 고정되며 풍력기둥 보다가 그 굵기가 더 작은 진 동막대가 달린 진동기둥;과 원형으로 된 진동부 원형 판의 가장자리 둘레에는 원형의 영구자석이 배치된 원형의 진동자석판;으로 이루어져서, 원형의 코일고정판은 고정기둥의 상측에서 수평방향으로 고정이 되어 원형의 진동 자석판이 원형의 코일고정판과 아주 가깝게 인접하면서 진동기둥의 막대에 결박이 된 상태에서 진동기둥과 함께 바람에 의하여 수평으로 흔들림에 따른 영구자석의 진동왕복운동에 의하여 인접한 코일고정판의 권선체에 감긴 코일에서는 연속적인 자기장의 변화로 인한 유도전기가 발생되도록 한다.
# Processing complete.

# %%
import fitz
import json
import requests
import os
import re

def download_pdf(url, filename):
    response = requests.get(url)
    with open(filename, 'wb') as f:
        f.write(response.content)

def clean_text(text):
    # 등록특허와 뒤에 나오는 숫자들 제거
    text = re.sub(r'등록특허\s*\d+(-\d+)*', '', text)
    # 페이지 번호 형식 (- 숫자 -) 제거
    text = re.sub(r'\s*-\s*\d+\s*-\s*', ' ', text)
    # 여러 줄의 공백을 하나의 공백으로 대체
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

def extract_content(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()

    content = {
        '청구항': '',
        '요약': ''
    }

    # 요약 추출
    summary_match = re.search(r'\(\d+\)\s*요\s*약(.*?)(?=청구범위|$)', full_text, re.DOTALL)
    if summary_match:
        summary = summary_match.group(1).strip()
        # 페이지 넘김 표시 제거
        summary = re.sub(r'\(뒷면에\s*계속\)\s*', '', summary)
        # 기울어진 텍스트 제거 (일반적으로 이탤릭체로 표시됨)
        summary = re.sub(r'<i>.*?</i>', '', summary)
        # "대 표 도 - 도" 제거
        summary = re.sub(r'대\s*표\s*도\s*-\s*도', '', summary)
        # 괄호 안의 숫자와 그 이후의 텍스트 제거
        summary = re.sub(r'\(\d+\).*$', '', summary, flags=re.DOTALL)
        # 텍스트 정리
        summary = clean_text(summary)
        content['요약'] = summary

    # 청구항 추출
    claims_match = re.search(r'청구범위(.*?)(?:발명의 설명|발명의 내용|과제의 해결 수단|$)', full_text, re.DOTALL)
    if claims_match:
        claims = claims_match.group(1).strip()
        claims = re.split(r'(청구항\s*\d+)', claims)
        if len(claims) > 1:
            content['청구항1'] = clean_text(claims[1] + claims[2])
            content['청구항_나머지'] = clean_text(''.join(claims[3:]))
        else:
            content['청구항'] = clean_text(claims[0])

    return content

# JSON 파일에서 특허 데이터 로드
input_file = '/home/user/hjkim/contextual/pdf_register_data(1-20,000).json'
with open(input_file, 'r') as f:
    patent_data = json.load(f)

# 처음 한 개의 PDF만 처리
for patent_number, pdf_url in list(patent_data.items())[:1]:
    pdf_filename = f"{patent_number}.pdf"
    print(f"\nProcessing patent number: {patent_number}")
    
    try:
        download_pdf(pdf_url, pdf_filename)
        content = extract_content(pdf_filename)
        
        print("\n청구항1:")
        print(content.get('청구항1', 'Not found'))
        
        print("\n청구항 나머지:")
        print(content.get('청구항_나머지', 'Not found'))
        
        print("\n요약:")
        print(content['요약'] if content['요약'] else 'Not found')
        
    except Exception as e:
        print(f"Error processing {patent_number}: {str(e)}")
    finally:
        if os.path.exists(pdf_filename):
            os.remove(pdf_filename)

print("Processing complete.")
# Out:
# Processing patent number: 1020170035102
#
# 청구항1:
# 청구항 1 소정의 형상과 재질로 되어서 일정길이를 가지며 하단부가 지면에 고정되는 한 개 이상의 고정기둥(10);과 중앙부에 소정크기의 구멍인 빈공간이 형성 된 고정부 원형 판(21)에서 빈 공간인 구멍의 외측 가장자리둘레 부 분을 따라 일정한 간격으로 보빈(bobbin)(221)에 코일(coil)(222)이 감겨진 다수의 권선체(22)들이 배열된 코일 고정판(20);과, 소정의 굵기와 재질과 형상으로 일정 길이를 가지며 내부가 비어 있거나 채워져 있는 풍력기둥(31)과, 풍력기둥 (31)의 하단에는 고정기둥(10)의 상측에 그 하단이 고정되도록 하는 소정의 길이를 가지며 그 단면의 크기(굵기)가 상기 풍력기둥(31)의 단면크기(굵기) 보다가 일정크기만큼 더 작은 진동막대(32)가 달린 진동기둥 (30);과 원형으로 된 진동부 원형 판(41)의 가장자리 근처의 둘레를 따라 원형의 영구자석(42)이 배치된 원형의 진동자 석판(40);으로 이루어져서, 원형의 코일고정판(20)은 그 외측둘레가 고정기둥(10)의 상부외측둘레에서 위쪽으로 돌출된 지지부재(23)에 지 지가 되어 고정이 되는 상태의 수평방향으로 배치가 되며 원형의 진동자석판(40)은 원형의 코일고정판(20)과 일 정거리 이격된 근접하는 위치에서 그 중심이 진동기둥(30)의 막대(32)에 결박되어 구속되는 상태의 수평방향으 로 배치가 되어 진동기둥(30)이 바람에 의하여 흔들리면서 진동을 함에 따라 진동자석판(40)은 그 중심이 진동 기둥(30) 아래쪽의 진동막대(32)에 결박되어 진동막대(32)와 함께 수평왕복의 진동운동을 하게 되어 고정기둥의 상측에서 진동자석판(40)과 가깝게 근접하여 고정된 코일고정판(20)의 권선체(22)에 감긴 코일(coil)(222)에는 영구자석(42)이 가깝게 근접하여 연속적으로 수평왕복의 진동운동을 하게 되고 그에 따라 코일(coil)(222)에서 는 연속적인 자기장의 변화와 함께 유도전기가 발생되도록 하는 것을 특징으로 하는 풍력진동발전기.
#
# 청구항 나머지:
# 청구항 2 청구항 1에 있어서, 원형의 진동자석판(40)과 원형의 코일고정판(20)은 각각 한 개 이상 여러 개를 구비하여 고정기둥(10)의 상측인 진동막대(32)부분에서 원형의 진동자석판(40)들과 원형의 코일고정판(20)들을 수직방향의 일정간격으로 하나씩 하나씩 교대로 번갈아가면서 서로 가깝게 인접하는 수평의 방향이 되도록 배치되는 것을 특징으로 하는 풍력진 동발전기. 청구항 3 청구항 1에 있어서, 진동기둥(30)의 상측이 되는 풍력기둥(31)은 위쪽으로 갈수록 단면이 점점 더 커지는 거꾸로 된 원추형의 모양 으로 구비가 되는 것을 특징으로 하는 풍력진동발전기. 청구항 4 청구항 1에 있어서, 진동기둥(30)의 상측이 되는 풍력기둥(31)의 상단부에는 소정의 무게를 가지는 무게장치(33)가 별도로 구비된 것을 특징으로 하는 풍력진동발전기. 청구항 5 청구항 1에 있어서, 진동기둥(30)의 상측이 되는 풍력기둥(31)에는 그 표면에 소정의 형상으로 된 다수의 돌기(311)들이 형성된 것 을 특징으로 하는 풍력진동발전기. 청구항 6 청구항 1에 있어서, 진동기둥(30)의 상측이 되는 풍력기둥(31)은 탄소섬유(carbon fiber) 또는 유리섬유(glass fiber) 또는 아라미 드섬유(aramid fiber)나 초고분자폴리에틸렌(UHMWPE)섬유 중의 어느 하나에 에폭시 등의 수지(樹脂, resin)제품 을 함침(含浸, impregnation)시킨 섬유강화복합재료의 재질로 형성이 되는 것을 특징으로 하는 풍력진동발전기. 청구항 7 청구항 1에 있어서, 진동기둥(30)의 하측이 되는 막대(32)는 강연선(鋼撚線, strand)으로 되거나 또는 탄소섬유(carbon fiber)나 유 리섬유(glass fiber)나 아라미드섬유(aramid fiber)나 초고분자폴리에틸렌(UHMWPE)섬유 중의 어느 하나에 에폭 시 등의 수지(樹脂, resin)제품을 함침(含浸, impregnation)시킨 섬유강화복합재료의 재질로 되는 것을 특징으 로 하는 풍력진동발전기. 청구항 8 청구항 1에 있어서, 권선체(22)에 감겨진 코일(coil)(222)의 중심축이 고정부 원형 판(21)의 중앙부에 형성된 빈 공간인 구멍의 외 측가장자리둘레 근처의 소정위치에서부터 수평의 방향으로 원형 판(21)의 외측바깥쪽으로 향하게 되는 방사선모 양으로 다수가 구비되는 것을 특징으로 하는 풍력진동발전기. 청구항 9 청구항 1에 있어서, 권선체(22)에 감겨진 코일(coil)(222)의 중심축이 수직인 상태에서 권선체(22)의 일 측 끝단은 고정부 원형 판 (21)의 위쪽으로 향하고 다른 일 측의 끝단은 고정부 원형 판(21)의 아래쪽으로 향하면서 그 중간은 고정부 원 형 판(21) 중앙부의 빈공간인 구멍의 외측가장자리둘레 근처의 소정위치에 있게 되는 상태로 고정부 원형 판 (21) 중앙부의 빈공간인 구멍의 외측가장자리둘레 근처를 따라 일정한 간격으로 다수의 권선체(22)가 구비되는 것을 특징으로 하는 풍력진동발전기.
#
# 요약:
# 본 발명은 풍력진동발전기에 관한 것으로서, 더 상세하게는 무게가 아주 가벼우면서도 바람에 아주 쉽게 잘 흔들 리는 진동기둥과 코일 및 영구자석으로 이루어지는 수평방향의 선형운동에 의한 진동발전기를 구비하여 바람에 의하여 흔들리는 풍력기둥의 수평진동에너지를 전기에너지로 전환을 시키도록 하는 날개가 없는 상태의 풍력진동 2 발전기를 아주 저렴한 비용으로서 제작을 하여 설치를 하도록 함과 동시에 날개가 없음으로 인한 높은 안전성으 로서 사람들과 친숙하게 일반 가정주택의 앞마당이나 주택인근의 산이나 유휴지, 공원, 야산, 들판, 공용도로의 주변 등 어디든 누구나가 쉽게 설치를 하여 발전을 할 수가 있도록 하는 현실적이고도 실용적인 회전날개가 없는 풍력진동발전기에 관한 것이다. 본 발명의 바람직한 일실시 예는 하단부가 지면에 고정되는 한 개 이상의 고정기둥;과 중심부에 소정크기의 구멍 인 빈공간이 형성 된 고정부 원형 판의 가장자리둘레를 따라 일정한 간격으로 다수의 권선체들이 배열된 코일고 정판;과, 길이가 긴 풍력기둥의 하단에는 고정기둥의 상측에서 고정되며 풍력기둥 보다가 그 굵기가 더 작은 진 동막대가 달린 진동기둥;과 원형으로 된 진동부 원형 판의 가장자리 둘레에는 원형의 영구자석이 배치된 원형의 진동자석판;으로 이루어져서, 원형의 코일고정판은 고정기둥의 상측에서 수평방향으로 고정이 되어 원형의 진동 자석판이 원형의 코일고정판과 아주 가깝게 인접하면서 진동기둥의 막대에 결박이 된 상태에서 진동기둥과 함께 바람에 의하여 수평으로 흔들림에 따른 영구자석의 진동왕복운동에 의하여 인접한 코일고정판의 권선체에 감긴 코일에서는 연속적인 자기장의 변화로 인한 유도전기가 발생되도록 한다.
# Processing complete.

# %% [markdown]
# ### 리트라이

# %%
# 대표도 뒤 문자, 숫자 생략
import fitz
import json
import requests
import os
import re
from tqdm import tqdm

def download_pdf(url, filename):
    response = requests.get(url)
    with open(filename, 'wb') as f:
        f.write(response.content)

def clean_text(text):
    # '대표도'와 그 뒤에 오는 모든 문자 및 숫자 제거 (줄 끝까지)
    text = re.sub(r'대\s*표\s*도\s*-?\s*도?\d*.*?(?=\n|$)', '', text, flags=re.DOTALL|re.MULTILINE)
    # '대표도' 단독으로 있을 때도 제거
    text = re.sub(r'\b대\s*표\s*도\b', '', text)

    # '명세서'와 그 앞뒤의 숫자 제거
    text = re.sub(r'\s*\d*\s*명\s*세\s*서\s*\d*\s*', ' ', text)
    
    # 등록특허와 뒤에 나오는 숫자들 제거
    text = re.sub(r'등록특허\s*\d+(-\d+)*', '', text)
    # 페이지 번호 형식 (- 숫자 -) 제거
    text = re.sub(r'\s*-\s*\d+\s*-\s*', '', text)
    # 여러 줄의 공백을 하나의 공백으로 대체
    text = re.sub(r'\s+', ' ', text)
    # 문장 끝에 남은 숫자 제거
    text = re.sub(r'\s*\d+\s*$', '', text)
    return text.strip()


def extract_content(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()

    content = {
        '청구항1': '',
        '그 외 청구항': '',
        '요약': ''
    }

    # 요약 추출
    summary_match = re.search(r'\(\d+\)\s*요\s*약(.*?)(?=청구범위|$)', full_text, re.DOTALL)
    if summary_match:
        summary = summary_match.group(1).strip()
        summary = re.sub(r'\(뒷면에\s*계속\)\s*', '', summary)
        summary = re.sub(r'<i>.*?</i>', '', summary)
        summary = re.sub(r'대\s*표\s*도\s*-\s*도', '', summary)
        summary = re.sub(r'\(\d+\).*$', '', summary, flags=re.DOTALL)
        summary = clean_text(summary)
        content['요약'] = summary

    # 청구항 추출
    claims_match = re.search(r'청구범위(.*?)(?:발명의 설명|발명의 내용|과제의 해결 수단|$)', full_text, re.DOTALL)
    if claims_match:
        claims = claims_match.group(1).strip()
        claims = re.split(r'(청구항\s*\d+)', claims)
        if len(claims) > 1:
            content['청구항1'] = clean_text(claims[1] + claims[2])
            content['그 외 청구항'] = clean_text(''.join(claims[3:]))
        else:
            content['청구항1'] = clean_text(claims[0])

    return content

# JSON 파일에서 특허 데이터 로드
input_file = '/home/user/hjkim/contextual/pdf_register_data(1-20,000).json'
output_file = '/home/user/hjkim/contextual/parsed_patent_data_10samples.json'

with open(input_file, 'r') as f:
    patent_data = json.load(f)

parsed_data = {}

# 처음 10개의 PDF만 처리
for patent_number, pdf_url in tqdm(list(patent_data.items())[:10], desc="Processing patents"):
    pdf_filename = f"{patent_number}.pdf"
    
    try:
        download_pdf(pdf_url, pdf_filename)
        content = extract_content(pdf_filename)
        
        parsed_data[patent_number] = {
            "청구항1": content['청구항1'],
            "그 외 청구항": content['그 외 청구항'],
            "요약": content['요약']
        }
        
    except Exception as e:
        print(f"Error processing {patent_number}: {str(e)}")
    finally:
        if os.path.exists(pdf_filename):
            os.remove(pdf_filename)

# 결과를 새 JSON 파일로 저장
with open(output_file, 'w', encoding='utf-8') as f:
    json.dump(parsed_data, f, ensure_ascii=False, indent=4)

print(f"Processing complete. Results saved to {output_file}")
# Out:
# Processing patents: 100%|██████████| 10/10 [04:14<00:00, 25.50s/it]
# Processing complete. Results saved to /home/user/hjkim/contextual/parsed_patent_data_10samples.json

# %%
# 유리판 문제 해결한 코드(10개)
import fitz
import json
import requests
import os
import re
from tqdm import tqdm

def download_pdf(url, filename):
    response = requests.get(url)
    with open(filename, 'wb') as f:
        f.write(response.content)

def clean_text(text):
    # '대표도'와 그 뒤에 오는 모든 문자 및 숫자 제거 (줄 끝까지)
    #text = re.sub(r'대\s*표\s*도\s*-\s*도?\d*.*?(?=\n|$)', '', text, flags=re.DOTALL|re.MULTILINE)
    text = re.sub(r'대\s*표\s*도.*', '', text)

    # '명세서'와 그 앞뒤의 숫자 제거
    text = re.sub(r'\s*\d*\s*명\s*세\s*서\s*\d*\s*', ' ', text)
    
    # 등록특허와 뒤에 나오는 숫자들 제거
    text = re.sub(r'등록특허\s*\d+(-\d+)*', '', text)
    # 페이지 번호 형식 (- 숫자 -) 제거
    text = re.sub(r'\s*-\s*\d+\s*-\s*', '', text)
    # 여러 줄의 공백을 하나의 공백으로 대체
    text = re.sub(r'\s+', ' ', text)
    # 문장 끝에 남은 숫자 제거
    #text = re.sub(r'\s*\d+\s*$', '', text)
    text = re.sub(r'\.\s*\(.*\)', '', text)  # 점 뒤에 괄호 시작하면 그 뒤는 모두 제거

    # 점 뒤에 숫자와 괄호가 함께 나오는 부분도 제거
    text = re.sub(r'\.\s*\d+\(\d+\).*', '', text)
    
    return text.strip()

def extract_content(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()

    content = {
        '청구항1': '',
        '그 외 청구항': '',
        '요약': ''
    }

    # 요약 추출
    summary_match = re.search(r'\(\d+\)\s*요\s*약(.*?)(?=청구범위|$)', full_text, re.DOTALL)
    if summary_match:
        summary = summary_match.group(1).strip()
        summary = re.sub(r'\(뒷면에\s*계속\)\s*', '', summary)
        summary = re.sub(r'<i>.*?</i>', '', summary)
        summary = re.sub(r'대\s*표\s*도\s*-\s*도', '', summary)
        #summary = re.sub(r'\(\d+\).*$', '', summary, flags=re.DOTALL)
        summary = clean_text(summary)
        content['요약'] = summary

    # 청구항 추출
    claims_match = re.search(r'청구범위(.*?)(?:발명의 설명|발명의 내용|과제의 해결 수단|$)', full_text, re.DOTALL)
    if claims_match:
        claims = claims_match.group(1).strip()
        claims = re.split(r'(청구항\s*\d+)', claims)
        if len(claims) > 1:
            content['청구항1'] = clean_text(claims[1] + claims[2])
            content['그 외 청구항'] = clean_text(''.join(claims[3:]))
        else:
            content['청구항1'] = clean_text(claims[0])

    return content

# JSON 파일에서 특허 데이터 로드
input_file = '/home/user/hjkim/contextual/pdf_register_data(1-20,000).json'
output_file = '/home/user/hjkim/contextual/parsed_patent_data_10samples.json'

with open(input_file, 'r') as f:
    patent_data = json.load(f)

parsed_data = {}

# 처음 10개의 PDF만 처리
for patent_number, pdf_url in tqdm(list(patent_data.items())[:10], desc="Processing patents"):
    pdf_filename = f"{patent_number}.pdf"
    
    try:
        download_pdf(pdf_url, pdf_filename)
        content = extract_content(pdf_filename)
        
        parsed_data[patent_number] = {
            "청구항1": content['청구항1'],
            "그 외 청구항": content['그 외 청구항'],
            "요약": content['요약']
        }
        
    except Exception as e:
        print(f"Error processing {patent_number}: {str(e)}")
    finally:
        if os.path.exists(pdf_filename):
            os.remove(pdf_filename)

# 결과를 새 JSON 파일로 저장
with open(output_file, 'w', encoding='utf-8') as f:
    json.dump(parsed_data, f, ensure_ascii=False, indent=4)

print(f"Processing complete. Results saved to {output_file}")

# %%
# 문제해결된 코드일지도??

import fitz
import json
import requests
import os
import re
from tqdm import tqdm

def download_pdf(url, filename):
    response = requests.get(url)
    with open(filename, 'wb') as f:
        f.write(response.content)



def clean_text(text):
    # '대표도'가 나오면 그 앞까지만 텍스트를 유지
    text = re.split(r'대\s*표\s*도', text)[0]
    # '명세서'와 그 앞뒤의 숫자 제거
    text = re.sub(r'\s*\d*\s*명\s*세\s*서\s*\d*\s*', ' ', text)
    # '선행기술조사문헌'과 그 뒤 모든 문자 제거
    text = re.sub(r'\(\d+\)\s*선행기술조사문헌.*', '', text, flags=re.DOTALL|re.MULTILINE)
    # CPC특허분류 제거
    text = re.sub(r'\(\d+\)\s*CPC특허분류.*', '', text, flags=re.DOTALL|re.MULTILINE)
    # 발명자 제거
    text = re.sub(r'\(\d+\)\s*발명자.*', '', text, flags=re.DOTALL|re.MULTILINE)
    # 등록특허와 뒤에 나오는 숫자들 제거
    text = re.sub(r'등록특허\s*\d+(-\d+)*', '', text)
    # 페이지 번호 형식 (- 숫자 -) 제거
    text = re.sub(r'\s*-\s*\d+\s*-\s*', '', text)
    # 여러 줄의 공백을 하나의 공백으로 대체
    text = re.sub(r'\s+', ' ', text)
    # 문장 끝에 남은 숫자 제거
    text = re.sub(r'\s*\d+\s*$', '', text)
    
    return text.strip()


def extract_content(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()

    content = {
        '청구항1': '',
        '그 외 청구항': '',
        '요약': ''
    }

    # 요약 추출
    summary_match = re.search(r'\(\d+\)\s*요\s*약(.*?)(?=청구범위|$)', full_text, re.DOTALL)
    if summary_match:
        summary = summary_match.group(1).strip()
        summary = re.sub(r'\(뒷면에\s*계속\)\s*', '', summary)
        summary = re.sub(r'<i>.*?</i>', '', summary)
        summary = re.sub(r'대\s*표\s*도\s*-\s*도', '', summary)
        #summary = re.sub(r'\(\d+\).*$', '', summary, flags=re.DOTALL)
        summary = clean_text(summary)
        content['요약'] = summary

    # 청구항 추출
    claims_match = re.search(r'청구범위(.*?)(?:발명의 설명|발명의 내용|과제의 해결 수단|$)', full_text, re.DOTALL)
    if claims_match:
        claims = claims_match.group(1).strip()
        claims = re.split(r'(청구항\s*\d+)', claims)
        if len(claims) > 1:
            content['청구항1'] = clean_text(claims[1] + claims[2])
            content['그 외 청구항'] = clean_text(''.join(claims[3:]))
        else:
            content['청구항1'] = clean_text(claims[0])

    return content

# JSON 파일에서 특허 데이터 로드
input_file = '/home/user/hjkim/contextual/random_test.json'
output_file = '/home/user/hjkim/contextual/random_test_result.json'

with open(input_file, 'r') as f:
    patent_data = json.load(f)

parsed_data = {}

# 처음 6개의 PDF만 처리
for patent_number, pdf_url in tqdm(list(patent_data.items())[:6], desc="Processing patents"):
    pdf_filename = f"{patent_number}.pdf"
    
    try:
        download_pdf(pdf_url, pdf_filename)
        content = extract_content(pdf_filename)
        
        parsed_data[patent_number] = {
            "청구항1": content['청구항1'],
            "그 외 청구항": content['그 외 청구항'],
            "요약": content['요약']
        }
        
    except Exception as e:
        print(f"Error processing {patent_number}: {str(e)}")
    finally:
        if os.path.exists(pdf_filename):
            os.remove(pdf_filename)

# 결과를 새 JSON 파일로 저장
with open(output_file, 'w', encoding='utf-8') as f:
    json.dump(parsed_data, f, ensure_ascii=False, indent=4)

print(f"Processing complete. Results saved to {output_file}")
# Out:
# Processing patents:   0%|          | 0/6 [00:00<?, ?it/s]
# Processing patents: 100%|██████████| 6/6 [00:16<00:00,  2.69s/it]
# Processing complete. Results saved to /home/user/hjkim/contextual/random_test_result.json

# %% [markdown]
# ## 전체 pdf 파싱(청구항1, 청구항 나머지, 요약)

# %%
import fitz
import json
import requests
import os
import re
from tqdm import tqdm

def download_pdf(url, filename):
    response = requests.get(url)
    with open(filename, 'wb') as f:
        f.write(response.content)



def clean_text(text):
    # '대표도'가 나오면 그 앞까지만 텍스트를 유지
    text = re.split(r'대\s*표\s*도', text)[0]
    # '명세서'와 그 앞뒤의 숫자 제거
    text = re.sub(r'\s*\d*\s*명\s*세\s*서\s*\d*\s*', ' ', text)
    # '선행기술조사문헌'과 그 뒤 모든 문자 제거
    text = re.sub(r'\(\d+\)\s*선행기술조사문헌.*', '', text, flags=re.DOTALL|re.MULTILINE)
    # CPC특허분류 제거
    text = re.sub(r'\(\d+\)\s*CPC특허분류.*', '', text, flags=re.DOTALL|re.MULTILINE)
    # 발명자 제거
    text = re.sub(r'\(\d+\)\s*발명자.*', '', text, flags=re.DOTALL|re.MULTILINE)
    # 등록특허와 뒤에 나오는 숫자들 제거
    text = re.sub(r'등록특허\s*\d+(-\d+)*', '', text)
    # 페이지 번호 형식 (- 숫자 -) 제거
    text = re.sub(r'\s*-\s*\d+\s*-\s*', '', text)
    # 여러 줄의 공백을 하나의 공백으로 대체
    text = re.sub(r'\s+', ' ', text)
    # 문장 끝에 남은 숫자 제거
    text = re.sub(r'\s*\d+\s*$', '', text)
    
    return text.strip()


def extract_content(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    for page in doc:
        full_text += page.get_text()
    doc.close()

    content = {
        '청구항1': '',
        '그 외 청구항': '',
        '요약': ''
    }

    # 요약 추출
    summary_match = re.search(r'\(\d+\)\s*요\s*약(.*?)(?=청구범위|$)', full_text, re.DOTALL)
    if summary_match:
        summary = summary_match.group(1).strip()
        summary = re.sub(r'\(뒷면에\s*계속\)\s*', '', summary)
        summary = re.sub(r'<i>.*?</i>', '', summary)
        summary = re.sub(r'대\s*표\s*도\s*-\s*도', '', summary)
        #summary = re.sub(r'\(\d+\).*$', '', summary, flags=re.DOTALL)
        summary = clean_text(summary)
        content['요약'] = summary

    # 청구항 추출
    claims_match = re.search(r'청구범위(.*?)(?:발명의 설명|발명의 내용|과제의 해결 수단|$)', full_text, re.DOTALL)
    if claims_match:
        claims = claims_match.group(1).strip()
        claims = re.split(r'(청구항\s*\d+)', claims)
        if len(claims) > 1:
            content['청구항1'] = clean_text(claims[1] + claims[2])
            content['그 외 청구항'] = clean_text(''.join(claims[3:]))
        else:
            content['청구항1'] = clean_text(claims[0])

    return content

# JSON 파일에서 특허 데이터 로드
input_file = '/home/user/hjkim/contextual/pdf_register_data(1-20,000).json'
output_file = '/home/user/hjkim/contextual/parsed_patent_data(1-20,000).json'

with open(input_file, 'r') as f:
    patent_data = json.load(f)

parsed_data = {}

# 모든 PDF 처리
for patent_number, pdf_url in tqdm(patent_data.items(), desc="Processing patents"):
    pdf_filename = f"{patent_number}.pdf"
    
    try:
        download_pdf(pdf_url, pdf_filename)
        content = extract_content(pdf_filename)
        
        parsed_data[patent_number] = {
            "청구항1": content['청구항1'],
            "그 외 청구항": content['그 외 청구항'],
            "요약": content['요약']
        }
        
    except Exception as e:
        print(f"Error processing {patent_number}: {str(e)}")
    finally:
        if os.path.exists(pdf_filename):
            os.remove(pdf_filename)

    # 메모리 관리를 위해 주기적으로 결과를 파일에 저장
    if len(parsed_data) % 1000 == 0:
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(parsed_data, f, ensure_ascii=False, indent=4)

# 최종 결과를 JSON 파일로 저장
with open(output_file, 'w', encoding='utf-8') as f:
    json.dump(parsed_data, f, ensure_ascii=False, indent=4)

print(f"Processing complete. Results saved to {output_file}")
# Out:
# Processing patents:  20%|█▉        | 3988/19999 [3:02:02<10:57:17,  2.46s/it]
# Error processing 1020170050481: Failed to open file '1020170050481.pdf'.
# Processing patents:  37%|███▋      | 7448/19999 [3:42:23<1:41:05,  2.07it/s]
# Error processing 1020170063290: Failed to open file '1020170063290.pdf'.
# Processing patents:  40%|███▉      | 7959/19999 [3:47:30<1:54:50,  1.75it/s]
# Error processing 1020170065295: Failed to open file '1020170065295.pdf'.
# Processing patents:  49%|████▉     | 9857/19999 [4:09:36<1:30:41,  1.86it/s]
# Error processing 1020170075637: Failed to open file '1020170075637.pdf'.
# Processing patents:  60%|█████▉    | 11995/19999 [5:56:51<7:10:42,  3.23s/it]
# Error processing 1020170085983: Failed to open file '1020170085983.pdf'.
# Processing patents:  80%|████████  | 16099/19999 [7:44:46<33:20,  1.95it/s]
# Error processing 1020170108192: Failed to open file '1020170108192.pdf'.
# Processing patents:  86%|████████▌ | 17127/19999 [7:54:19<22:34,  2.12it/s]
# Error processing 1020170114631: Failed to open file '1020170114631.pdf'.
# Processing patents: 100%|██████████| 19999/19999 [8:21:16<00:00,  1.50s/it]
# Processing complete. Results saved to /home/user/hjkim/contextual/parsed_patent_data(1-20,000).json

# %% [markdown]
# ### full_data.json에서 에러 특허번호 데이터 삭제

# %%
import json
import shutil
import os

# 에러가 발생한 특허번호 리스트
error_patents = [
    '1020170050481', '1020170063290', '1020170065295', '1020170075637',
    '1020170085983', '1020170108192', '1020170114631', '1020150089525',
    '1020150093885', '1020150112973', '1020150131001', '1020150131514',
    '1020150135500', '1020150135821', '1020150139984', '1020150144988'
]

# 원본 JSON 파일 경로
original_json_path = '/media/user/datadisk/Patent_data/full_data.json'

# 새로운 JSON 파일 경로
new_json_path = '/media/user/datadisk/Patent_data/full_data_error_deleted.json'

# 원본 파일을 새 이름으로 복사
shutil.copy2(original_json_path, new_json_path)

# 새로 복사된 JSON 파일 읽기
with open(new_json_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 원본 항목 수 저장
original_count = len(data['items'])

# 에러가 발생한 특허번호에 해당하는 항목 삭제
data['items'] = [item for item in data['items'] if item['applicationNumber'] not in error_patents]

# 삭제된 항목 수 계산
deleted_count = original_count - len(data['items'])

# 수정된 데이터를 새 JSON 파일로 저장
with open(new_json_path, 'w', encoding='utf-8') as file:
    json.dump(data, file, ensure_ascii=False, indent=4)

print(f"원본 파일: {original_json_path}")
print(f"수정된 파일: {new_json_path}")
print(f"총 {deleted_count}개의 에러 특허 데이터가 삭제되었습니다.")
print(f"원본 항목 수: {original_count}")
print(f"수정 후 항목 수: {len(data['items'])}")
# Out:
# 원본 파일: /media/user/datadisk/Patent_data/full_data.json
# 수정된 파일: /media/user/datadisk/Patent_data/full_data_error_deleted.json
# 총 23개의 에러 특허 데이터가 삭제되었습니다.
# 원본 항목 수: 147861
# 수정 후 항목 수: 147838

# %%
import json

# 에러가 발생한 특허번호 리스트
# error_patents = [
#     '1020170050481', '1020170063290', '1020170065295', '1020170075637',
#     '1020170085983', '1020170108192', '1020170114631', '1020150089525',
#     '1020150093885', '1020150112973', '1020150131001', '1020150131514',
#     '1020150135500', '1020150135821', '1020150139984', '1020150144988'
# ]

# JSON 파일 경로
json_file_path = '/media/user/datadisk/Patent_data/full_data_error_deleted.json'

# JSON 파일 읽기
with open(json_file_path, 'r', encoding='utf-8') as file:
    data = json.load(file)

# 에러가 발생한 특허번호에 해당하는 항목 삭제
data['items'] = [item for item in data['items'] if item['applicationNumber'] not in error_patents]

# 수정된 데이터를 JSON 파일로 저장
with open(json_file_path, 'w', encoding='utf-8') as file:
    json.dump(data, file, ensure_ascii=False, indent=4)

print(f"에러가 발생한 {len(error_patents)}개의 특허 데이터가 삭제되었습니다.")

# %% [markdown]
# ## 성은프로님의 20001부터 시작하는 코드와 합치기

# %%
import json

# 입력 파일 경로
file1 = '/home/user/hjkim/contextual/claim/parsed_patent_data(1-20,000).json'
file2 = '/home/user/hjkim/contextual/claim/parsed_patent_data(20001-).json'

# 출력 파일 경로
output_file = '/home/user/hjkim/contextual/claim/merged_parsed_patent_data.json'

# 두 파일의 내용을 저장할 리스트
merged_data = []

# 첫 번째 파일 읽기
with open(file1, 'r', encoding='utf-8') as f1:
    data1 = json.load(f1)
    merged_data.extend(data1)

# 두 번째 파일 읽기
with open(file2, 'r', encoding='utf-8') as f2:
    data2 = json.load(f2)
    merged_data.extend(data2)

# 병합된 데이터를 새 파일에 쓰기
with open(output_file, 'w', encoding='utf-8') as outfile:
    json.dump(merged_data, outfile, ensure_ascii=False, indent=2)

print(f"병합된 데이터가 {output_file}에 저장되었습니다.")
